# %%
# Instalo lo necesario
! python -m pip install py2neo neo4jupyter
import requests
from datetime import datetime
import json
import sys
import py2neo
from py2neo import Graph, Node, Relationship
import neo4jupyter
neo4jupyter.init_notebook_mode()
# Out:
# Requirement already satisfied: py2neo in /usr/local/lib/python3.10/dist-packages (2021.2.3)
# Requirement already satisfied: neo4jupyter in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from py2neo) (2023.5.7)
# Requirement already satisfied: interchange~=2021.0.4 in /usr/local/lib/python3.10/dist-packages (from py2neo) (2021.0.4)
# Requirement already satisfied: monotonic in /usr/local/lib/python3.10/dist-packages (from py2neo) (1.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from py2neo) (23.1)
# Requirement already satisfied: pansi>=2020.7.3 in /usr/local/lib/python3.10/dist-packages (from py2neo) (2020.7.3)
# Requirement already satisfied: pygments>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from py2neo) (2.14.0)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from py2neo) (1.16.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from py2neo) (1.26.16)
# Requirement already satisfied: IPython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from neo4jupyter) (7.34.0)
# Requirement already satisfied: ipython-cypher>=0.2.4 in /usr/local/lib/python3.10/dist-packages (from neo4jupyter) (0.2.6)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from interchange~=2021.0.4->py2neo) (2022.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from IPython>=4.0.0->neo4jupyter) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from IPython>=4.0.0->neo4jupyter) (0.18.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from IPython>=4.0.0->neo4jupyter) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from IPython>=4.0.0->neo4jupyter) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from IPython>=4.0.0->neo4jupyter) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from IPython>=4.0.0->neo4jupyter) (3.0.38)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from IPython>=4.0.0->neo4jupyter) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from IPython>=4.0.0->neo4jupyter) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from IPython>=4.0.0->neo4jupyter) (4.8.0)
# Requirement already satisfied: neo4jrestclient>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from ipython-cypher>=0.2.4->neo4jupyter) (2.1.1)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from ipython-cypher>=0.2.4->neo4jupyter) (0.7.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->IPython>=4.0.0->neo4jupyter) (0.8.3)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from neo4jrestclient>=2.1.0->ipython-cypher>=0.2.4->neo4jupyter) (2.27.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->IPython>=4.0.0->neo4jupyter) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython>=4.0.0->neo4jupyter) (0.2.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.1.0->neo4jrestclient>=2.1.0->ipython-cypher>=0.2.4->neo4jupyter) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.1.0->neo4jrestclient>=2.1.0->ipython-cypher>=0.2.4->neo4jupyter) (3.4)

# %%
# url de la BD
dburl='neo4j+s://053b5ce0.databases.neo4j.io'

# usuario y pass a la BD
user='neo4j'
pasw='FU9eXzRPH16jq7VblzQfIEJMe-NgP4WW8nWs-dFm4jM'

# conexión a la BD
graph = Graph(dburl, auth=(user, pasw))

# %%
# Función que crea el nodo de un evento si no existe y si ya existe retorna el nodo existente.
def crear_evento(graph, net, code, ids, tipo, title, place, mag, time, url, detail, latitud, longitud, z):
  try:
    # Consulta si ya existe un nodo "evento" con el id dado
    query = "MATCH (e:Evento) WHERE e.net = $net and e.code = $code RETURN e"
    result = graph.run(query, net=net, code=code).data()

    if not result:
        # El nodo no existe, así que lo creamos
        print('Creando evento: ',net, code, '(', latitud, ',', longitud, ',', z,')')
        location = py2neo.data.spatial.CartesianPoint((latitud, longitud, z))
        event_node = Node("Evento",net=net, code=code, ids=ids, coordenadas=location, magnitud=mag, fecha=time, web=url, tipo=tipo, titulo=title, lugar=place, detalle=detail)
        graph.create(event_node)
    else:
        # El nodo ya existe, obtenemos una referencia a él
        print('El evento ya existía', net, code)
        event_node = result[0]["e"]

    return event_node
  except Exception as e:
    try:
      # El grafo está vacío, creamos el primer nodo
      print('Creando evento: ',net, code, '(', latitud, ',', longitud, ',', z,')')
      location = py2neo.data.spatial.CartesianPoint((latitud, longitud, z))
      event_node = Node("Evento",net=net, code=code, ids=ids, coordenadas=location, magnitud=mag, fecha=time, web=url, tipo=tipo, titulo=title, lugar=place, detalle=detail)
      graph.create(event_node)
      return event_node
    except Exception as e:
      print ('Error al crear evento en linea {}'.format(sys.exc_info()[-1].tb_lineno))
      raise e




# Función que crea el nodo de una ciudad si no existe y si ya existe retorna el nodo existente.
def crear_ciudad(graph, latitud, longitud, nombre):
  try:
    # Consulta si ya existe un nodo "ciudad" con las coordenadas dadas
    location = py2neo.data.spatial.CartesianPoint((latitud, longitud))
    query = "MATCH (c:Ciudad) WHERE c.coordenadas = $location RETURN c"
    result = graph.run(query, location = location).data()

    if not result:
        # El nodo no existe, así que lo creamos
        print('Creando ciudad', nombre)
        ciudad_node = Node("Ciudad", coordenadas = location, nombre = nombre)
        graph.create(ciudad_node)
    else:
        print('La ciudad ya existía', nombre)
        # El nodo ya existe, obtenemos una referencia a él
        ciudad_node = result[0]["c"]

    return ciudad_node
  except Exception as e:
    try:
      # El grafo está vacío, creamos el primer nodo
      print('Creando ciudad', nombre)
      ciudad_node = Node("Ciudad", coordenadas = location, nombre = nombre)
      graph.create(ciudad_node)
      return ciudad_node
    except Exception as e:
      print ('Error al crear ciudad en linea {}'.format(sys.exc_info()[-1].tb_lineno))
      raise e



# Función que crea el arco entre un nodo ciudad y un nodo evento, si ese arco no existe y si ya existe retorna el existente.
def crear_arco(graph, evento, ciudad, distance, direction):
    # Consulta si ya existe un arco entre ciudad y evento
    query = "MATCH (evento)-[r:NEARBY]->(ciudad) WHERE ID(evento) = $evento_id AND ID(ciudad) = $ciudad_id RETURN r"
    result = graph.run(query, evento_id=evento.identity, ciudad_id=ciudad.identity).data()

    if not result:
        # El arco no existe, así que lo creamos
        arco = Relationship(evento, "NEARBY", ciudad, distancia=distance, direccion=direction)
        graph.create(arco)
    else:
        print('Ya existía arco')
        # El nodo ya existe, obtenemos una referencia a él
        arco = result[0]["r"]

    return arco

# %%
# función que obtiene todos los eventos para una zona geográfica y rango de fechas especificados
def get_earthquake_data(start_date, end_date, minlatitude, maxlatitude, minlongitude, maxlongitude):
    # url WebService de USGS
    url_usgs = "https://earthquake.usgs.gov/fdsnws/event/1/query"
    # Parameters for the API request
    params = {
        "format": "geojson",
        "starttime": start_date,
        "endtime": end_date,
        "minlatitude" : minlatitude,
        "maxlatitude" : maxlatitude,
        "minlongitude" : minlongitude,
        "maxlongitude" : maxlongitude
        #"includeallorigins": "true"
    }
    # Sending the API request and getting the response
    response = requests.get(url_usgs, params=params)

    if response.status_code == 200:
        data = response.json()
        return data
    else:
        print("Error occurred while fetching earthquake data.")
        print(response)
        return None

def process_event(feature):
  try:
    # obtengo los datos del evento
    properties = feature["properties"]
    geometry = feature["geometry"]
    [lat, long, z] = geometry["coordinates"]
    place = properties["place"]
    net = properties["net"]
    code = properties["code"]
    mag = properties["mag"]
    time = properties["time"]
    url = properties["url"]
    detail = properties["detail"]
    ids = properties["ids"]
    tipo = properties["type"]
    title = properties["title"]

    fecha = datetime.utcfromtimestamp(time/1000)

    # creo el nodo evento
    event_node = crear_evento(graph, net, code, ids, tipo, title, place, mag, fecha, url, detail, lat, long, float(z))

    # consulto la url de detalles para obtener las ciudades cercanas
    response = requests.get(detail)
    if response.status_code == 200:
      data = response.json()
      #print(data)
      properties = data["properties"]
      prod = properties["products"]
      # si existe un producto del tipo nearby-cities, proceso la información existente, referente a las ciudades cercanas
      if("nearby-cities" in prod):
        nbcities = prod["nearby-cities"][0]
        content = nbcities["contents"]["nearby-cities.json"]
        # obtengo las cidades cercanas
        url2 = content["url"]
        response2 = requests.get(url2)
        if response2.status_code == 200:
          cities = response2.json()
          #recorro todas las ciudades de la colección
          for city in cities:
            city_name = city["name"]
            city_lat = city["latitude"]
            city_long = city["longitude"]
            city_node = crear_ciudad(graph, city_long, city_lat, city_name)
            dist= city["distance"]
            direc = city["direction"]
            crear_arco(graph, event_node, city_node, dist, direc)

        else:
          print(response2.headers)
    else:
      print(response.headers)

  except Exception as e:
    print('Error en linea {}'.format(sys.exc_info()[-1].tb_lineno))
    print( str(e) )
    print('No detail')
    return []

# %%
# defino los límites de la zona geográfica a consultar
maxlatitude = 44
minlatitude = 30
maxlongitude = -114
minlongitude = -125

# ya cargamos datos desde el 24 de mayo en delante
# defino rango de fechas para la consulta
start_date = "2023-05-24"
end_date = "2023-06-25"

# Obtengo los datos de eventos en el rango de fechas especificado
earthquake_data = get_earthquake_data(start_date, end_date, minlatitude, maxlatitude, minlongitude, maxlongitude)


# Proceso los datos obtenidos
if earthquake_data:
    # Extraigo la info de los eventos
    features = earthquake_data["features"]
    # recorro y proceso los eventos obtenidos
    for feature in features:
      process_event(feature)
# Out:
# El evento ya existía nc 73904846
# 2.204940546644569
# La ciudad ya existía San Martin, California
# Ya existía arco
# La ciudad ya existía Morgan Hill, California
# Ya existía arco
# La ciudad ya existía Gilroy, California
# Ya existía arco
# La ciudad ya existía Interlaken, California
# Ya existía arco
# La ciudad ya existía Corralitos, California
# Ya existía arco
# El evento ya existía nc 73904841
# 2.204940546644569
# 1.1069316771812328
# La ciudad ya existía Daly City, California
# Ya existía arco
# La ciudad ya existía Colma, California
# Ya existía arco
# La ciudad ya existía San Francisco Zoo, California
# Ya existía arco
# La ciudad ya existía Pacifica, California
# Ya existía arco
# La ciudad ya existía South San Francisco, California
# Ya existía arco
# El evento ya existía ci 40494512
# 1.1069316771812328
# La ciudad ya existía Lytle Creek, CA
# Ya existía arco
# La ciudad ya existía Devore, CA
# Ya existía arco
# La ciudad ya existía Rancho Cucamonga, CA
# Ya existía arco
# La ciudad ya existía Fontana, CA
# Ya existía arco
# La ciudad ya existía Muscoy, CA
# Ya existía arco
# El evento ya existía nc 73904836
# 3.35682582139003
# La ciudad ya existía Pacifica, California
# Ya existía arco
# La ciudad ya existía San Bruno, California
# Ya existía arco
# La ciudad ya existía Colma, California
# Ya existía arco
# La ciudad ya existía South San Francisco, California
# Ya existía arco
# La ciudad ya existía Millbrae, California
# Ya existía arco
# El evento ya existía nc 73904831
# 3.35682582139003
# La ciudad ya existía The Geysers, California
# Ya existía arco
# La ciudad ya existía Cloverdale, California
# Ya existía arco
# La ciudad ya existía Cobb, California
# Ya existía arco
# La ciudad ya existía Kelseyville, California
# Ya existía arco
# La ciudad ya existía Anderson Springs, California
# Ya existía arco
# El evento ya existía ci 40494496
# La ciudad ya existía Ocotillo Wells, CA
# Ya existía arco
# La ciudad ya existía Borrego Springs, CA
# Ya existía arco
# La ciudad ya existía Julian, CA
# Ya existía arco
# La ciudad ya existía Pine Valley, CA
# Ya existía arco
# La ciudad ya existía Warner Springs, CA
# Ya existía arco
# El evento ya existía ci 40494480
# 36.77369719154618
# 1.033774106811408
# 1.9046357101517308
# 1.9102482396984144
# 1.6721384146467173
# 1.4629006824743451
# La ciudad ya existía Borrego Springs, CA
# Ya existía arco
# La ciudad ya existía Oasis, CA
# Ya existía arco
# La ciudad ya existía Ocotillo Wells, CA
# Ya existía arco
# La ciudad ya existía Salton City, CA
# Ya existía arco
# La ciudad ya existía Mecca, CA
# Ya existía arco
# El evento ya existía ci 37552628
# 36.77369719154618
# 1.0624765984330877
# 2.0054802680142667
# 2.010838569635948
# 1.7495831703732532
# 1.5207288777987142
# La ciudad ya existía Borrego Springs, CA
# Ya existía arco
# La ciudad ya existía Oasis, CA
# Ya existía arco
# La ciudad ya existía Ocotillo Wells, CA
# Ya existía arco
# La ciudad ya existía Salton City, CA
# Ya existía arco
# La ciudad ya existía Mecca, CA
# Ya existía arco
# El evento ya existía nc 73904826
# 1.033774106811408
# 1.0624765984330877
# 1.1722066995611415
# 1.1796080884535551
# 1.1627144779241845
# 1.5016698220049314
# La ciudad ya existía Redwood Valley, California
# Ya existía arco
# La ciudad ya existía Ukiah, California
# Ya existía arco
# La ciudad ya existía Willits, California
# Ya existía arco
# La ciudad ya existía Talmage, California
# Ya existía arco
# La ciudad ya existía Brooktrails, California
# Ya existía arco
# El evento ya existía ci 37552612
# 1.9046357101517308
# 2.0054802680142667
# 1.1722066995611415
# 12.674123871398875
# 12.47703879484674
# 1.419333262712768
# 1.4033245070562903
# 1.054671637841022
# La ciudad ya existía Searles Valley, CA
# Ya existía arco
# La ciudad ya existía Ridgecrest, CA
# Ya existía arco
# La ciudad ya existía Trona, CA
# Ya existía arco
# La ciudad ya existía Inyokern, CA
# Ya existía arco
# La ciudad ya existía Johannesburg, CA
# Ya existía arco
# El evento ya existía ci 40494472
# 1.9102482396984144
# 2.010838569635948
# 1.1796080884535551
# 12.674123871398875
# 7.274824768400299
# 1.4907798324815738
# 1.4448074473533847
# La ciudad ya existía California City, CA
# Ya existía arco
# La ciudad ya existía Mojave, CA
# Ya existía arco
# La ciudad ya existía Tehachapi, CA
# Ya existía arco
# La ciudad ya existía Edwards Air Force Base, CA
# Ya existía arco
# La ciudad ya existía Rosamond, CA
# Ya existía arco
# El evento ya existía ci 37552620
# 1.6721384146467173
# 1.7495831703732532
# 1.1627144779241845
# 12.47703879484674
# 7.274824768400299
# 1.5083255985950774
# 1.376449032353709
# 1.1515951113509462
# La ciudad ya existía Searles Valley, CA
# Ya existía arco
# La ciudad ya existía Trona, CA
# Ya existía arco
# La ciudad ya existía Little Lake, CA
# Ya existía arco
# La ciudad ya existía Coso Junction, CA
# Ya existía arco
# La ciudad ya existía Ridgecrest, CA
# Ya existía arco
# El evento ya existía nc 73904816
# 1.5016698220049314
# 1.419333262712768
# 1.4907798324815738
# 1.5083255985950774
# 1.1304425597338743
# 1.0923030633936837
# La ciudad ya existía Portola Valley, California
# Ya existía arco
# La ciudad ya existía Los Altos Hills, California
# Ya existía arco
# La ciudad ya existía Stanford, California
# Ya existía arco
# La ciudad ya existía Woodside, California
# Ya existía arco
# La ciudad ya existía Los Altos, California
# Ya existía arco
# El evento ya existía ci 40494464
# 1.4629006824743451
# 1.5207288777987142
# 1.4033245070562903
# 1.4448074473533847
# 1.376449032353709
# 1.1304425597338743
# 1.1526630949245742
# La ciudad ya existía Pine Valley, CA
# Ya existía arco
# La ciudad ya existía Ocotillo Wells, CA
# Ya existía arco
# La ciudad ya existía Julian, CA
# Ya existía arco
# La ciudad ya existía Ocotillo, CA
# Ya existía arco
# La ciudad ya existía Borrego Springs, CA
# Ya existía arco
# El evento ya existía nc 73904811
# 1.0923030633936837
# 1.3742083526452837
# La ciudad ya existía Cape Vizcaino, California
# Ya existía arco
# La ciudad ya existía Rockport, California
# Ya existía arco
# La ciudad ya existía Fort Bragg, California
# Ya existía arco
# La ciudad ya existía Laytonville, California
# Ya existía arco
# La ciudad ya existía Mendocino, California
# Ya existía arco
# El evento ya existía ci 40494456
# 1.054671637841022
# 1.1515951113509462
# 1.1526630949245742
# 1.3742083526452837
# La ciudad ya existía Searles Valley, CA
# Ya existía arco
# La ciudad ya existía Trona, CA
# Ya existía arco
# La ciudad ya existía Little Lake, CA
# Ya existía arco
# La ciudad ya existía Coso Junction, CA
# Ya existía arco
# La ciudad ya existía Ridgecrest, CA
# Ya existía arco
# El evento ya existía ci 40494408
# La ciudad ya existía San Jacinto, CA
# Ya existía arco
# La ciudad ya existía Hemet, CA
# Ya existía arco
# La ciudad ya existía Green Acres, CA
# Ya existía arco
# La ciudad ya existía Beaumont, CA
# Ya existía arco
# La ciudad ya existía Valle Vista, CA
# Ya existía arco
# El evento ya existía nc 73904801
# 1.2369796973565244
# 1.1157560959796564
# La ciudad ya existía Hollister, California
# Ya existía arco
# La ciudad ya existía Ridgemark, California
# Ya existía arco
# La ciudad ya existía San Juan Bautista, California
# Ya existía arco
# La ciudad ya existía Tres Pinos, California
# Ya existía arco
# La ciudad ya existía Aromas, California
# Ya existía arco
# El evento ya existía ci 40494392
# 1.2369796973565244
# 1.5917009278027252
# La ciudad ya existía Lake Henshaw, CA
# Ya existía arco
# La ciudad ya existía Julian, CA
# Ya existía arco
# La ciudad ya existía Warner Springs, CA
# Ya existía arco
# La ciudad ya existía San Diego Country Estates, CA
# Ya existía arco
# La ciudad ya existía Ramona, CA
# Ya existía arco
# El evento ya existía ci 40494384
# 1.1157560959796564
# 1.5917009278027252
# La ciudad ya existía Ridgecrest, CA
# Ya existía arco
# La ciudad ya existía Searles Valley, CA
# Ya existía arco
# La ciudad ya existía Trona, CA
# Ya existía arco
# La ciudad ya existía Inyokern, CA
# Ya existía arco
# La ciudad ya existía Little Lake, CA
# Ya existía arco
# El evento ya existía nc 73904796
# La ciudad ya existía Lakeport, California
# Ya existía arco
# La ciudad ya existía North Lakeport, California
# Ya existía arco
# La ciudad ya existía Talmage, California
# Ya existía arco
# La ciudad ya existía Kelseyville, California
# Ya existía arco
# La ciudad ya existía Ukiah, California
# Ya existía arco
# El evento ya existía nc 73904791
# 3.3035364763813284
# La ciudad ya existía The Geysers, California
# Ya existía arco
# La ciudad ya existía Cobb, California
# Ya existía arco
# La ciudad ya existía Anderson Springs, California
# Ya existía arco
# La ciudad ya existía Middletown, California
# Ya existía arco
# La ciudad ya existía Hidden Valley Lake, California
# Ya existía arco
# El evento ya existía nn 00861690
# 3.3035364763813284
# El evento ya existía nn 00861680
# 1.8579591491425602
# 1.8269089640343976
# El evento ya existía nc 73904786
# 1.8579591491425602
# 1.7913086559229265
# 1.0146091633133807
# La ciudad ya existía Hollister, California
# Ya existía arco
# La ciudad ya existía Ridgemark, California
# Ya existía arco
# La ciudad ya existía San Juan Bautista, California
# Ya existía arco
# La ciudad ya existía Tres Pinos, California
# Ya existía arco
# La ciudad ya existía Aromas, California
# Ya existía arco
# El evento ya existía ci 40494352
# 1.8269089640343976
# 1.7913086559229265
# La ciudad ya existía Pearblossom, CA
# Ya existía arco
# La ciudad ya existía Littlerock, CA
# Ya existía arco
# La ciudad ya existía Llano, CA
# Ya existía arco
# La ciudad ya existía Vincent, CA
# Ya existía arco
# La ciudad ya existía Palmdale, CA
# Ya existía arco
# El evento ya existía nc 73904781
# 1.0146091633133807
# La ciudad ya existía The Geysers, California
# Ya existía arco
# La ciudad ya existía Cobb, California
# Ya existía arco
# La ciudad ya existía Anderson Springs, California
# Ya existía arco
# La ciudad ya existía Kelseyville, California
# Ya existía arco
# La ciudad ya existía Cloverdale, California
# Ya existía arco
# El evento ya existía nc 73904761
# 2.0025798856715515
# La ciudad ya existía The Geysers, California
# Ya existía arco
# La ciudad ya existía Cobb, California
# Ya existía arco
# La ciudad ya existía Anderson Springs, California
# Ya existía arco
# La ciudad ya existía Cloverdale, California
# Ya existía arco
# La ciudad ya existía Middletown, California
# Ya existía arco
# El evento ya existía nc 73904751
# 2.0025798856715515
# La ciudad ya existía Cobb, California
# Ya existía arco
# La ciudad ya existía The Geysers, California
# Ya existía arco
# La ciudad ya existía Anderson Springs, California
# Ya existía arco
# La ciudad ya existía Kelseyville, California
# Ya existía arco
# La ciudad ya existía Cloverdale, California
# Ya existía arco
# El evento ya existía nc 73904741
# La ciudad ya existía San Martin, California
# Ya existía arco
# La ciudad ya existía Morgan Hill, California
# Ya existía arco
# La ciudad ya existía Gilroy, California
# Ya existía arco
# La ciudad ya existía Interlaken, California
# Ya existía arco
# La ciudad ya existía Aromas, California
# Ya existía arco
# El evento ya existía nc 73904726
# 1.1256520788428097
# La ciudad ya existía Petrolia, California
# Ya existía arco
# La ciudad ya existía Ferndale, California
# Ya existía arco
# La ciudad ya existía Fortuna, California
# Ya existía arco
# La ciudad ya existía Humboldt Hill, California
# Ya existía arco
# La ciudad ya existía Rio Dell, California
# Ya existía arco
# El evento ya existía nc 73904721
# 1.1256520788428097
# 1.8070497688926148
# La ciudad ya existía Toms Place, California
# Ya existía arco
# La ciudad ya existía Mammoth Lakes, California
# Ya existía arco
# La ciudad ya existía Round Valley, California
# Ya existía arco
# La ciudad ya existía West Bishop, California
# Ya existía arco
# La ciudad ya existía Dixon Lane-Meadow Creek, California
# Ya existía arco
# El evento ya existía ci 40494280
# 1.8070497688926148
# La ciudad ya existía Bodfish, CA
# Ya existía arco
# La ciudad ya existía Lake Isabella, CA
# Ya existía arco
# La ciudad ya existía Wofford Heights, CA
# Ya existía arco
# La ciudad ya existía Kernville, CA
# Ya existía arco
# La ciudad ya existía Tehachapi, CA
# Ya existía arco
# El evento ya existía nc 73904716
# 1.3298297680843965
# La ciudad ya existía Pinnacles, California
# Ya existía arco
# La ciudad ya existía King City, California
# Ya existía arco
# La ciudad ya existía Greenfield, California
# Ya existía arco
# La ciudad ya existía New Idria, California
# Ya existía arco
# La ciudad ya existía San Lucas, California
# Ya existía arco
# El evento ya existía ci 40494240
# 1.3298297680843965
# La ciudad ya existía Nipomo, CA
# Ya existía arco
# La ciudad ya existía Santa Maria, CA
# Ya existía arco
# Creando ciudad Simmler, CA
# Error al crear ciudad en linea 61
# Error en linea 73
# [Request.Invalid] Illegal value for field "params": Expected FLOAT64 but got INT8
# No detail
# El evento ya existía nc 73904706
# La ciudad ya existía Hydesville, California
# Ya existía arco
# La ciudad ya existía Willow Creek, California
# Ya existía arco
# La ciudad ya existía Rio Dell, California
# Ya existía arco
# La ciudad ya existía Blue Lake, California
# Ya existía arco
# La ciudad ya existía Hayfork, California
# Ya existía arco
# El evento ya existía nc 73904701
# 1.1454601762281273
# La ciudad ya existía The Geysers, California
# Ya existía arco
# La ciudad ya existía Cobb, California
# Ya existía arco
# La ciudad ya existía Anderson Springs, California
# Ya existía arco
# La ciudad ya existía Middletown, California
# Ya existía arco
# La ciudad ya existía Hidden Valley Lake, California
# Ya existía arco
# El evento ya existía ci 40494216
# 1.1454601762281273
# La ciudad ya existía Rialto, CA
# Ya existía arco
# La ciudad ya existía Muscoy, CA
# Ya existía arco
# La ciudad ya existía Fontana, CA
# Ya existía arco
# La ciudad ya existía Bloomington, CA
# Ya existía arco
# La ciudad ya existía Devore, CA
# Ya existía arco
# El evento ya existía nc 73904696
# La ciudad ya existía The Geysers, California
# Ya existía arco
# La ciudad ya existía Cobb, California
# Ya existía arco
# La ciudad ya existía Anderson Springs, California
# Ya existía arco
# La ciudad ya existía Middletown, California
# Ya existía arco
# La ciudad ya existía Cloverdale, California
# Ya existía arco
# El evento ya existía ci 40494176
# La ciudad ya existía Ridgecrest, CA
# Ya existía arco
# La ciudad ya existía Searles Valley, CA
# Ya existía arco
# La ciudad ya existía Trona, CA
# Ya existía arco
# La ciudad ya existía Inyokern, CA
# Ya existía arco
# La ciudad ya existía Johannesburg, CA
# Ya existía arco
# El evento ya existía ci 40494152
# 1.091727058725502
# 2.0138634053332276
# La ciudad ya existía Anza, CA
# La ciudad ya existía Warner Springs, CA
# La ciudad ya existía Aguanga, CA
# La ciudad ya existía Borrego Springs, CA
# La ciudad ya existía Palomar Observatory, CA
# El evento ya existía nc 73904686
# 1.091727058725502
# 2.694076919235988
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Cloverdale, California
# La ciudad ya existía Kelseyville, California
# El evento ya existía ci 40494144
# 2.0138634053332276
# 1.2647050035066274
# La ciudad ya existía Banning, CA
# La ciudad ya existía Cabazon, CA
# La ciudad ya existía Valle Vista, CA
# La ciudad ya existía San Jacinto, CA
# La ciudad ya existía Beaumont, CA
# El evento ya existía nc 73904676
# 2.694076919235988
# 1.2647050035066274
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Cloverdale, California
# La ciudad ya existía Kelseyville, California
# El evento ya existía ci 40494112
# 1.7029592896235852
# La ciudad ya existía Pine Valley, CA
# La ciudad ya existía Ocotillo Wells, CA
# La ciudad ya existía Julian, CA
# La ciudad ya existía Ocotillo, CA
# La ciudad ya existía Borrego Springs, CA
# El evento ya existía nc 73904671
# 1.5641926408517515
# 1.4273085272634287
# 1.3307036559513046
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Cloverdale, California
# La ciudad ya existía Kelseyville, California
# El evento ya existía ci 40494104
# 1.7029592896235852
# 1.5641926408517515
# 1.5121300164220293
# La ciudad ya existía Little Lake, CA
# La ciudad ya existía Coso Junction, CA
# La ciudad ya existía Inyokern, CA
# La ciudad ya existía Searles Valley, CA
# La ciudad ya existía Ridgecrest, CA
# El evento ya existía nc 73904666
# 1.4273085272634287
# 1.7873960608721546
# 19.51190815362616
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Cloverdale, California
# La ciudad ya existía Middletown, California
# El evento ya existía ci 40494088
# 1.5121300164220293
# 1.7873960608721546
# 1.7639726263908322
# 1.0959246340439683
# 1.0561371765045957
# La ciudad ya existía Little Lake, CA
# La ciudad ya existía Coso Junction, CA
# La ciudad ya existía Inyokern, CA
# La ciudad ya existía Olancha, CA
# La ciudad ya existía Ridgecrest, CA
# El evento ya existía nc 73904661
# 1.3307036559513046
# 19.51190815362616
# 1.7639726263908322
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Cloverdale, California
# La ciudad ya existía Kelseyville, California
# El evento ya existía ci 40494072
# 1.0959246340439683
# 28.541083607952817
# 1.1645252110946882
# La ciudad ya existía Pine Valley, CA
# La ciudad ya existía Ocotillo Wells, CA
# La ciudad ya existía Julian, CA
# La ciudad ya existía Ocotillo, CA
# La ciudad ya existía Borrego Springs, CA
# El evento ya existía ci 40494064
# 1.0561371765045957
# 28.541083607952817
# 1.2139531039829534
# La ciudad ya existía Pine Valley, CA
# La ciudad ya existía Ocotillo Wells, CA
# La ciudad ya existía Julian, CA
# La ciudad ya existía Ocotillo, CA
# La ciudad ya existía Borrego Springs, CA
# El evento ya existía nc 73904656
# 1.1645252110946882
# 1.2139531039829534
# 1.7256624260596984
# 1.3646156153603193
# La ciudad ya existía Pinnacles, California
# La ciudad ya existía Soledad, California
# La ciudad ya existía Tres Pinos, California
# La ciudad ya existía Gonzales, California
# La ciudad ya existía Ridgemark, California
# El evento ya existía nc 73904651
# 1.7256624260596984
# 1.417104289078275
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Middletown, California
# La ciudad ya existía Hidden Valley Lake, California
# El evento ya existía nc 73904646
# 1.3646156153603193
# 1.417104289078275
# 2.0714714166041213
# La ciudad ya existía Pinnacles, California
# La ciudad ya existía Tres Pinos, California
# La ciudad ya existía Soledad, California
# La ciudad ya existía Gonzales, California
# La ciudad ya existía Ridgemark, California
# El evento ya existía ci 40494040
# 2.0714714166041213
# La ciudad ya existía Searles Valley, CA
# La ciudad ya existía Trona, CA
# La ciudad ya existía Ridgecrest, CA
# La ciudad ya existía Johannesburg, CA
# La ciudad ya existía Inyokern, CA
# El evento ya existía nc 73904641
# La ciudad ya existía Redwood Valley, California
# La ciudad ya existía Willits, California
# La ciudad ya existía Brooktrails, California
# La ciudad ya existía Ukiah, California
# La ciudad ya existía Lake Pillsbury, California
# El evento ya existía ci 40494024
# La ciudad ya existía Banning, CA
# La ciudad ya existía Cabazon, CA
# La ciudad ya existía Beaumont, CA
# La ciudad ya existía Calimesa, CA
# La ciudad ya existía Yucaipa, CA
# El evento ya existía nc 73904636
# 1.4253558090099963
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Kelseyville, California
# La ciudad ya existía Cloverdale, California
# El evento ya existía nc 73904631
# 1.4253558090099963
# 1.0229578064810025
# 1.0366825486824571
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Middletown, California
# La ciudad ya existía Hidden Valley Lake, California
# El evento ya existía ci 40494016
# 1.0229578064810025
# 2.595828852913639
# La ciudad ya existía San Jacinto, CA
# La ciudad ya existía Valle Vista, CA
# La ciudad ya existía Banning, CA
# La ciudad ya existía Hemet, CA
# La ciudad ya existía Beaumont, CA
# El evento ya existía ci 40494008
# 1.0366825486824571
# 2.595828852913639
# 1.4386206505693666
# La ciudad ya existía Ridgecrest, CA
# La ciudad ya existía Searles Valley, CA
# La ciudad ya existía Trona, CA
# La ciudad ya existía Inyokern, CA
# La ciudad ya existía Johannesburg, CA
# El evento ya existía nn 00861686
# 1.4386206505693666
# El evento ya existía nc 73904621
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Middletown, California
# La ciudad ya existía Hidden Valley Lake, California
# El evento ya existía ci 40493952
# 1.1692233331899549
# La ciudad ya existía Anza, CA
# La ciudad ya existía Warner Springs, CA
# La ciudad ya existía Borrego Springs, CA
# La ciudad ya existía La Quinta, CA
# La ciudad ya existía Palm Desert, CA
# El evento ya existía nc 73904616
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Cloverdale, California
# La ciudad ya existía Kelseyville, California
# El evento ya existía ci 40493936
# 1.1692233331899549
# La ciudad ya existía Calimesa, CA
# La ciudad ya existía Yucaipa, CA
# La ciudad ya existía Mentone, CA
# La ciudad ya existía Redlands, CA
# La ciudad ya existía Moreno Valley, CA
# El evento ya existía nn 00861689
# 1.2891884882432523
# El evento ya existía nc 73904611
# 1.2891884882432523
# La ciudad ya existía Cobb, California
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Lower Lake, California
# La ciudad ya existía Middletown, California
# El evento ya existía ci 40493928
# 2.579174489602629
# La ciudad ya existía Progreso, B.C., MX
# La ciudad ya existía Heber, CA
# La ciudad ya existía El Centro, CA
# La ciudad ya existía Calexico, CA
# La ciudad ya existía Mexicali, B.C., MX
# El evento ya existía nc 73904601
# La ciudad ya existía Willits, California
# La ciudad ya existía Brooktrails, California
# La ciudad ya existía Redwood Valley, California
# La ciudad ya existía Lake Pillsbury, California
# La ciudad ya existía Ukiah, California
# El evento ya existía ci 40493920
# 2.579174489602629
# La ciudad ya existía Julian, CA
# La ciudad ya existía San Diego Country Estates, CA
# La ciudad ya existía Warner Springs, CA
# La ciudad ya existía Pine Valley, CA
# La ciudad ya existía Lake Henshaw, CA
# El evento ya existía ci 40493912
# 1.4526754410848888
# La ciudad ya existía Frazier Park, CA
# La ciudad ya existía Gorman, CA
# La ciudad ya existía Pine Mountain Club, CA
# La ciudad ya existía Lebec, CA
# La ciudad ya existía Grapevine, CA
# El evento ya existía ci 40493904
# 1.4526754410848888
# La ciudad ya existía Olancha, CA
# La ciudad ya existía Coso Junction, CA
# La ciudad ya existía Little Lake, CA
# La ciudad ya existía Lone Pine, CA
# La ciudad ya existía Kernville, CA
# El evento ya existía nc 73904596
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Kelseyville, California
# La ciudad ya existía Cloverdale, California
# El evento ya existía ci 40493888
# 1.669703675677476
# Creando ciudad Canoga Park, CA
# Creando ciudad Woodland Hills, CA
# Creando ciudad Tarzana, CA
# Creando ciudad Reseda, CA
# Creando ciudad West Hills, CA
# El evento ya existía nc 73904591
# 1.669703675677476
# 1.6335256371085514
# La ciudad ya existía Markleeville, California
# La ciudad ya existía Alpine Village, California
# La ciudad ya existía Mesa Vista, California
# La ciudad ya existía Kirkwood, California
# Creando ciudad Bear Valley, California
# El evento ya existía nc 73904586
# 1.6335256371085514
# 1.386027152672374
# La ciudad ya existía Cobb, California
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Kelseyville, California
# La ciudad ya existía Cloverdale, California
# El evento ya existía ci 40493880
# 1.1121782399467774
# 1.1322074776374753
# 1.2616802831593883
# La ciudad ya existía Barstow, CA
# La ciudad ya existía Fort Irwin, CA
# La ciudad ya existía Ludlow, CA
# Creando ciudad San Bernardino, CA
# La ciudad ya existía Twentynine Palms, CA
# La ciudad ya existía Palm Springs, CA
# El evento ya existía nc 73904576
# 1.386027152672374
# 1.1121782399467774
# 1.660721117839433
# 2.583781049501056
# La ciudad ya existía Lakeport, California
# La ciudad ya existía Talmage, California
# La ciudad ya existía North Lakeport, California
# La ciudad ya existía Ukiah, California
# La ciudad ya existía Kelseyville, California
# El evento ya existía nn 00861688
# 1.1322074776374753
# 1.660721117839433
# 2.1665862500728967
# 1.1898401937452825
# El evento ya existía nc 73904571
# 2.583781049501056
# 2.1665862500728967
# 1.099707925392656
# La ciudad ya existía Cobb, California
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Kelseyville, California
# La ciudad ya existía Cloverdale, California
# El evento ya existía ci 40493872
# 1.2616802831593883
# 1.1898401937452825
# 1.099707925392656
# 1.5636667916645504
# 1.2602772270932454
# La ciudad ya existía Idyllwild, CA
# La ciudad ya existía Anza, CA
# La ciudad ya existía Valle Vista, CA
# La ciudad ya existía Hemet, CA
# La ciudad ya existía Palm Springs, CA
# El evento ya existía ci 40493864
# 1.5636667916645504
# 5.554055014085602
# 1.0970365956336103
# La ciudad ya existía Wrightwood, CA
# La ciudad ya existía Lytle Creek, CA
# La ciudad ya existía Phelan, CA
# La ciudad ya existía Pinon Hills, CA
# La ciudad ya existía Rancho Cucamonga, CA
# El evento ya existía ci 40493856
# 1.2602772270932454
# 5.554055014085602
# 1.337835455705812
# La ciudad ya existía Searles Valley, CA
# La ciudad ya existía Trona, CA
# La ciudad ya existía Ridgecrest, CA
# La ciudad ya existía Inyokern, CA
# La ciudad ya existía Johannesburg, CA
# El evento ya existía ci 40493848
# 1.0970365956336103
# 1.337835455705812
# 1.376496519709672
# La ciudad ya existía Ridgecrest, CA
# La ciudad ya existía Searles Valley, CA
# La ciudad ya existía Trona, CA
# La ciudad ya existía Inyokern, CA
# La ciudad ya existía Johannesburg, CA
# El evento ya existía ci 40493840
# 1.376496519709672
# La ciudad ya existía Anza, CA
# La ciudad ya existía Warner Springs, CA
# La ciudad ya existía Aguanga, CA
# La ciudad ya existía Palomar Observatory, CA
# La ciudad ya existía Lake Henshaw, CA
# El evento ya existía nc 73904566
# Creando ciudad Angwin, California
# Creando ciudad Saint Helena, California
# Creando ciudad St. Helena, California
# Creando ciudad Calistoga, California
# Creando ciudad Kenwood, California
# El evento ya existía ci 40493832
# 2.411645694199323
# La ciudad ya existía Idyllwild, CA
# La ciudad ya existía Anza, CA
# La ciudad ya existía Valle Vista, CA
# La ciudad ya existía Hemet, CA
# La ciudad ya existía San Jacinto, CA
# El evento ya existía ci 40493824
# 2.411645694199323
# La ciudad ya existía Anza, CA
# La ciudad ya existía La Quinta, CA
# La ciudad ya existía Borrego Springs, CA
# La ciudad ya existía Palm Desert, CA
# La ciudad ya existía Warner Springs, CA
# El evento ya existía ci 40493816
# 2.5145234492127444
# La ciudad ya existía Yucaipa, CA
# La ciudad ya existía Calimesa, CA
# La ciudad ya existía Beaumont, CA
# La ciudad ya existía Mentone, CA
# La ciudad ya existía Banning, CA
# El evento ya existía ci 40493808
# 2.5145234492127444
# La ciudad ya existía Borrego Springs, CA
# La ciudad ya existía Julian, CA
# La ciudad ya existía Warner Springs, CA
# La ciudad ya existía Ocotillo Wells, CA
# La ciudad ya existía Lake Henshaw, CA
# El evento ya existía ci 40493792
# 3.9431568542555806
# 1.1388505635948099
# La ciudad ya existía Searles Valley, CA
# La ciudad ya existía Trona, CA
# La ciudad ya existía Ridgecrest, CA
# La ciudad ya existía Inyokern, CA
# La ciudad ya existía Johannesburg, CA
# El evento ya existía ci 40493784
# 3.9431568542555806
# La ciudad ya existía Redlands, CA
# La ciudad ya existía Mentone, CA
# La ciudad ya existía Yucaipa, CA
# La ciudad ya existía Calimesa, CA
# La ciudad ya existía Loma Linda, CA
# El evento ya existía nn 00861666
# 1.1388505635948099
# El evento ya existía ci 40493768
# 1.6731971907111463
# La ciudad ya existía San Jacinto, CA
# La ciudad ya existía Valle Vista, CA
# La ciudad ya existía Banning, CA
# La ciudad ya existía Hemet, CA
# La ciudad ya existía Beaumont, CA
# El evento ya existía nn 00861674
# 1.6731971907111463
# El evento ya existía nc 73904561
# 2.391186471989642
# 1.0117256082045
# La ciudad ya existía Mammoth Lakes, California
# La ciudad ya existía Toms Place, California
# La ciudad ya existía Lee Vining, California
# La ciudad ya existía Round Valley, California
# La ciudad ya existía Yosemite Valley, California
# El evento ya existía ci 40493760
# 2.391186471989642
# La ciudad ya existía Grapevine, CA
# La ciudad ya existía Pine Mountain Club, CA
# La ciudad ya existía Frazier Park, CA
# La ciudad ya existía Lebec, CA
# La ciudad ya existía Gorman, CA
# El evento ya existía nc 73904556
# 1.0117256082045
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Kelseyville, California
# La ciudad ya existía Cloverdale, California
# El evento ya existía nc 73904551
# 1.2031947937188636
# 2.4832548172548488
# 1.7726394355677795
# La ciudad ya existía Cobb, California
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Middletown, California
# La ciudad ya existía Kelseyville, California
# El evento ya existía ci 40493752
# 1.2031947937188636
# 1.283572057053878
# 1.4083872922720653
# La ciudad ya existía La Quinta, CA
# La ciudad ya existía Anza, CA
# La ciudad ya existía Palm Desert, CA
# La ciudad ya existía Borrego Springs, CA
# La ciudad ya existía Indian Wells, CA
# El evento ya existía nc 71130749
# 2.4832548172548488
# 1.283572057053878
# 3.8836223821322347
# La ciudad ya existía Gilroy, California
# La ciudad ya existía San Martin, California
# La ciudad ya existía Morgan Hill, California
# La ciudad ya existía Aromas, California
# La ciudad ya existía Interlaken, California
# El evento ya existía nc 73904546
# 1.7726394355677795
# 1.4083872922720653
# 3.8836223821322347
# La ciudad ya existía Mammoth Lakes, California
# La ciudad ya existía Toms Place, California
# La ciudad ya existía Round Valley, California
# La ciudad ya existía Lee Vining, California
# La ciudad ya existía Yosemite Valley, California
# El evento ya existía ci 40493736
# 1.8389779824229173
# 1.220100875773238
# La ciudad ya existía Ocotillo Wells, CA
# La ciudad ya existía Pine Valley, CA
# La ciudad ya existía Ocotillo, CA
# La ciudad ya existía Julian, CA
# La ciudad ya existía Borrego Springs, CA
# El evento ya existía ci 40493728
# 1.8389779824229173
# 3.4699911392695264
# La ciudad ya existía Wrightwood, CA
# La ciudad ya existía Lytle Creek, CA
# La ciudad ya existía Phelan, CA
# La ciudad ya existía Pinon Hills, CA
# La ciudad ya existía Rancho Cucamonga, CA
# El evento ya existía ci 40493720
# 1.220100875773238
# 3.4699911392695264
# La ciudad ya existía Frazier Park, CA
# La ciudad ya existía Gorman, CA
# La ciudad ya existía Pine Mountain Club, CA
# La ciudad ya existía Lebec, CA
# La ciudad ya existía Grapevine, CA
# El evento ya existía nc 73904541
# 3.9850476722498516
# 1.5636540647556139
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Cloverdale, California
# La ciudad ya existía Kelseyville, California
# El evento ya existía nc 73904536
# 3.9850476722498516
# 2.450662789483929
# 1.0300241858237353
# La ciudad ya existía Portola Valley, California
# La ciudad ya existía Los Altos Hills, California
# La ciudad ya existía Loyola, California
# La ciudad ya existía Los Altos, California
# La ciudad ya existía Stanford, California
# El evento ya existía nc 73904531
# 1.5636540647556139
# 2.450662789483929
# 1.723143256790211
# La ciudad ya existía Huron, California
# La ciudad ya existía Coalinga, California
# La ciudad ya existía Avenal, California
# La ciudad ya existía Kettleman City, California
# La ciudad ya existía Lemoore Station, California
# El evento ya existía ci 40493704
# 1.0300241858237353
# 1.723143256790211
# La ciudad ya existía Little Lake, CA
# La ciudad ya existía Coso Junction, CA
# La ciudad ya existía Searles Valley, CA
# La ciudad ya existía Inyokern, CA
# La ciudad ya existía Trona, CA
# El evento ya existía nc 73904526
# 1.3203051046935457
# 1.1774008149440618
# La ciudad ya existía Gilroy, California
# La ciudad ya existía San Martin, California
# La ciudad ya existía Morgan Hill, California
# La ciudad ya existía Aromas, California
# La ciudad ya existía San Juan Bautista, California
# El evento ya existía ci 40493696
# 1.3203051046935457
# La ciudad ya existía Borrego Springs, CA
# La ciudad ya existía Ocotillo Wells, CA
# La ciudad ya existía Oasis, CA
# La ciudad ya existía Salton City, CA
# La ciudad ya existía Warner Springs, CA
# El evento ya existía nc 73904521
# 1.1774008149440618
# 2.555288769600419
# 2.1987189886522644
# La ciudad ya existía Cobb, California
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Middletown, California
# La ciudad ya existía Lower Lake, California
# El evento ya existía nc 73904511
# 2.555288769600419
# 12.918574612327067
# 1.4079812772326823
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Middletown, California
# La ciudad ya existía Hidden Valley Lake, California
# El evento ya existía nc 73904516
# 2.1987189886522644
# 12.918574612327067
# 1.3684145329202055
# La ciudad ya existía Boonville, California
# La ciudad ya existía Cloverdale, California
# La ciudad ya existía Talmage, California
# La ciudad ya existía Ukiah, California
# La ciudad ya existía Sea Ranch, California
# El evento ya existía nc 73904506
# 1.4079812772326823
# 1.3684145329202055
# La ciudad ya existía Toms Place, California
# La ciudad ya existía Mammoth Lakes, California
# La ciudad ya existía Round Valley, California
# La ciudad ya existía West Bishop, California
# La ciudad ya existía Dixon Lane-Meadow Creek, California
# El evento ya existía nc 73904501
# 1.4555305839188053
# La ciudad ya existía Gilroy, California
# La ciudad ya existía San Martin, California
# La ciudad ya existía Morgan Hill, California
# La ciudad ya existía Aromas, California
# La ciudad ya existía Interlaken, California
# El evento ya existía ci 40493672
# 1.372692748705934
# La ciudad ya existía Anza, CA
# La ciudad ya existía Warner Springs, CA
# La ciudad ya existía Aguanga, CA
# La ciudad ya existía Palomar Observatory, CA
# La ciudad ya existía Lake Henshaw, CA
# El evento ya existía nc 73904496
# 1.4555305839188053
# 1.372692748705934
# 2.1217840228278226
# La ciudad ya existía Pinnacles, California
# La ciudad ya existía Soledad, California
# La ciudad ya existía Greenfield, California
# La ciudad ya existía Tres Pinos, California
# La ciudad ya existía Gonzales, California
# El evento ya existía nc 73904491
# 2.1217840228278226
# 1.742598493798421
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Cloverdale, California
# La ciudad ya existía Kelseyville, California
# El evento ya existía nc 73904486
# 1.742598493798421
# 1.6266342692899902
# 1.9896686565620716
# 1.6033755651329387
# 1.5788332225918411
# La ciudad ya existía Cobb, California
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Kelseyville, California
# La ciudad ya existía Cloverdale, California
# El evento ya existía nc 73904481
# 1.6266342692899902
# 1.6588494101460651
# 1.37515617184944
# 1.3560937925055043
# 1.1294372314380847
# La ciudad ya existía San Simeon, California
# La ciudad ya existía Lopez Point, California
# La ciudad ya existía Cambria, California
# La ciudad ya existía Lake Nacimiento, California
# La ciudad ya existía San Ardo, California
# El evento ya existía nc 73904476
# 1.9896686565620716
# 1.6588494101460651
# 6.670837630019737
# 6.259071328138727
# 1.067860250074147
# La ciudad ya existía Cloverdale, California
# La ciudad ya existía Kelseyville, California
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Lakeport, California
# El evento ya existía nc 73904466
# 1.6033755651329387
# 1.37515617184944
# 6.670837630019737
# 97.79070356222378
# 1.2674982093096812
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Cloverdale, California
# La ciudad ya existía Middletown, California
# El evento ya existía nc 73904471
# 1.5788332225918411
# 1.3560937925055043
# 6.259071328138727
# 97.79070356222378
# 1.283350194351389
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Cloverdale, California
# La ciudad ya existía Middletown, California
# El evento ya existía ci 40493664
# 1.1294372314380847
# 1.067860250074147
# 1.2674982093096812
# 1.283350194351389
# La ciudad ya existía Bodfish, CA
# La ciudad ya existía Lake Isabella, CA
# La ciudad ya existía Wofford Heights, CA
# La ciudad ya existía Kernville, CA
# La ciudad ya existía Tehachapi, CA
# El evento ya existía nc 73904451
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Kelseyville, California
# La ciudad ya existía Cloverdale, California
# El evento ya existía nc 73904446
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Middletown, California
# La ciudad ya existía Cloverdale, California
# El evento ya existía nc 73904441
# 1.530049798626356
# 1.5219767210655621
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Middletown, California
# La ciudad ya existía Hidden Valley Lake, California
# El evento ya existía nn 00861664
# 1.530049798626356
# 2.026256427227874
# El evento ya existía nc 73904436
# 1.5219767210655621
# 2.026256427227874
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Middletown, California
# La ciudad ya existía Hidden Valley Lake, California
# El evento ya existía nc 73904431
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Cloverdale, California
# La ciudad ya existía Kelseyville, California
# El evento ya existía nc 73904426
# La ciudad ya existía Willow Creek, California
# La ciudad ya existía Blue Lake, California
# La ciudad ya existía Bayside, California
# La ciudad ya existía Arcata, California
# Creando ciudad Myrtletown, California
# El evento ya existía nc 73904421
# 2.381779118828368
# La ciudad ya existía Nice, California
# La ciudad ya existía Upper Lake, California
# La ciudad ya existía North Lakeport, California
# La ciudad ya existía Lakeport, California
# La ciudad ya existía Soda Bay, California
# El evento ya existía nc 73904416
# 2.381779118828368
# La ciudad ya existía Ferndale, California
# La ciudad ya existía Fortuna, California
# La ciudad ya existía Petrolia, California
# La ciudad ya existía Rio Dell, California
# La ciudad ya existía Hydesville, California
# El evento ya existía ci 40493632
# La ciudad ya existía Home Gardens, CA
# La ciudad ya existía Corona, CA
# La ciudad ya existía Norco, CA
# La ciudad ya existía Pedley, CA
# La ciudad ya existía Riverside, CA
# El evento ya existía ci 40493616
# La ciudad ya existía Ridgecrest, CA
# La ciudad ya existía Inyokern, CA
# La ciudad ya existía Searles Valley, CA
# La ciudad ya existía Trona, CA
# La ciudad ya existía Johannesburg, CA
# El evento ya existía nc 73904396
# La ciudad ya existía Cobb, California
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Kelseyville, California
# La ciudad ya existía Soda Bay, California
# El evento ya existía nc 73904391
# La ciudad ya existía Morgan Hill, California
# La ciudad ya existía Seven Trees, California
# La ciudad ya existía Alum Rock, California
# La ciudad ya existía San Martin, California
# La ciudad ya existía San Jose, California
# El evento ya existía nc 73904386
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Middletown, California
# La ciudad ya existía Kelseyville, California
# El evento ya existía nc 73904381
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Cloverdale, California
# La ciudad ya existía Kelseyville, California
# El evento ya existía nn 00861649
# El evento ya existía nc 73904371
# 43.120316651227085
# 2.9871941353738176
# La ciudad ya existía Cobb, California
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Kelseyville, California
# La ciudad ya existía Soda Bay, California
# El evento ya existía nc 73904366
# 43.120316651227085
# 3.1947197641155167
# La ciudad ya existía Cobb, California
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Kelseyville, California
# La ciudad ya existía Lower Lake, California
# El evento ya existía nc 73904361
# 2.9871941353738176
# 3.1947197641155167
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Kelseyville, California
# La ciudad ya existía Cloverdale, California
# El evento ya existía nn 00861647
# El evento ya existía nc 73904351
# La ciudad ya existía Cobb, California
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Kelseyville, California
# La ciudad ya existía Soda Bay, California
# El evento ya existía nn 00861642
# El evento ya existía uw 61926587
# El evento ya existía ci 40493368
# La ciudad ya existía Home Gardens, CA
# La ciudad ya existía Corona, CA
# La ciudad ya existía Norco, CA
# La ciudad ya existía Woodcrest, CA
# La ciudad ya existía Riverside, CA
# El evento ya existía nc 73904336
# La ciudad ya existía Pinnacles, California
# La ciudad ya existía Soledad, California
# La ciudad ya existía Greenfield, California
# La ciudad ya existía Gonzales, California
# La ciudad ya existía Tres Pinos, California
# El evento ya existía ci 40493336
# 4.610736084770396
# 1.0667258561087725
# La ciudad ya existía Beaumont, CA
# La ciudad ya existía Calimesa, CA
# La ciudad ya existía Yucaipa, CA
# La ciudad ya existía Banning, CA
# La ciudad ya existía Mentone, CA
# El evento ya existía ci 40493328
# 4.610736084770396
# 1.2528088427758195
# La ciudad ya existía Idyllwild, CA
# La ciudad ya existía Anza, CA
# La ciudad ya existía Valle Vista, CA
# La ciudad ya existía Hemet, CA
# La ciudad ya existía San Jacinto, CA
# El evento ya existía nc 73904321
# 1.0667258561087725
# 1.2528088427758195
# 2.553750898394462
# 1.2696508523160213
# La ciudad ya existía Pinnacles, California
# La ciudad ya existía Soledad, California
# La ciudad ya existía Greenfield, California
# La ciudad ya existía Gonzales, California
# La ciudad ya existía King City, California
# El evento ya existía nc 73904316
# 2.553750898394462
# 1.4204410247162353
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Middletown, California
# La ciudad ya existía Hidden Valley Lake, California
# El evento ya existía nc 73904311
# 1.2696508523160213
# 1.4204410247162353
# Creando ciudad Fremont, California
# La ciudad ya existía Sunol, California
# Creando ciudad Union City, California
# Creando ciudad Newark, California
# La ciudad ya existía Pleasanton, California
# El evento ya existía ci 40493296
# La ciudad ya existía Julian, CA
# La ciudad ya existía Borrego Springs, CA
# La ciudad ya existía Pine Valley, CA
# La ciudad ya existía Ocotillo Wells, CA
# La ciudad ya existía Warner Springs, CA
# El evento ya existía ci 40493248
# La ciudad ya existía Anza, CA
# La ciudad ya existía Aguanga, CA
# La ciudad ya existía Idyllwild, CA
# La ciudad ya existía Valle Vista, CA
# La ciudad ya existía Hemet, CA
# El evento ya existía nc 73904301
# 2.145610165639896
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Middletown, California
# La ciudad ya existía Hidden Valley Lake, California
# El evento ya existía nc 73904296
# 2.145610165639896
# La ciudad ya existía Mammoth Lakes, California
# La ciudad ya existía Toms Place, California
# La ciudad ya existía Lee Vining, California
# La ciudad ya existía Round Valley, California
# La ciudad ya existía Yosemite Valley, California
# El evento ya existía nn 00861630
# El evento ya existía nc 73904286
# 106.49918962352159
# 1.3261642020766533
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Cloverdale, California
# La ciudad ya existía Kelseyville, California
# El evento ya existía nc 71130744
# 106.49918962352159
# 1.3181816344086983
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Middletown, California
# La ciudad ya existía Hidden Valley Lake, California
# El evento ya existía nc 73904281
# 1.3261642020766533
# 1.3181816344086983
# La ciudad ya existía Fortuna, California
# La ciudad ya existía Ferndale, California
# La ciudad ya existía Hydesville, California
# La ciudad ya existía Rio Dell, California
# La ciudad ya existía Humboldt Hill, California
# El evento ya existía nc 73904276
# La ciudad ya existía Mammoth Lakes, California
# La ciudad ya existía Toms Place, California
# La ciudad ya existía Lee Vining, California
# La ciudad ya existía Round Valley, California
# La ciudad ya existía Yosemite Valley, California
# El evento ya existía ci 40493104
# La ciudad ya existía Ocotillo Wells, CA
# La ciudad ya existía Julian, CA
# La ciudad ya existía Borrego Springs, CA
# La ciudad ya existía Pine Valley, CA
# La ciudad ya existía Warner Springs, CA
# El evento ya existía ci 40493072
# La ciudad ya existía Borrego Springs, CA
# La ciudad ya existía Oasis, CA
# La ciudad ya existía Warner Springs, CA
# La ciudad ya existía Ocotillo Wells, CA
# La ciudad ya existía Mecca, CA
# El evento ya existía nc 73904271
# 1.1262172538030957
# La ciudad ya existía Redwood Valley, California
# La ciudad ya existía Willits, California
# La ciudad ya existía Ukiah, California
# La ciudad ya existía Brooktrails, California
# La ciudad ya existía Talmage, California
# El evento ya existía nc 73904266
# 1.1262172538030957
# La ciudad ya existía Mammoth Lakes, California
# La ciudad ya existía Toms Place, California
# La ciudad ya existía Lee Vining, California
# La ciudad ya existía Round Valley, California
# La ciudad ya existía Yosemite Valley, California
# El evento ya existía ci 40492952
# La ciudad ya existía Ocotillo Wells, CA
# La ciudad ya existía Pine Valley, CA
# La ciudad ya existía Ocotillo, CA
# La ciudad ya existía Julian, CA
# La ciudad ya existía Borrego Springs, CA
# El evento ya existía ci 40492920
# 1.1982331494712755
# 1.257356878630246
# La ciudad ya existía Ensenada, B.C., MX
# La ciudad ya existía El Sauzal, B.C., MX
# La ciudad ya existía Maneadero, B.C., MX
# La ciudad ya existía Primo Tapia, B.C., MX
# La ciudad ya existía Tijuana, B.C., MX
# El evento ya existía ci 40492912
# 1.1982331494712755
# 1.874044980423542
# La ciudad ya existía Searles Valley, CA
# La ciudad ya existía Ridgecrest, CA
# La ciudad ya existía Trona, CA
# La ciudad ya existía Inyokern, CA
# La ciudad ya existía Johannesburg, CA
# El evento ya existía ci 40492896
# 1.257356878630246
# 1.874044980423542
# La ciudad ya existía Borrego Springs, CA
# La ciudad ya existía Ocotillo Wells, CA
# La ciudad ya existía Oasis, CA
# La ciudad ya existía Salton City, CA
# La ciudad ya existía Warner Springs, CA
# El evento ya existía ci 40492848
# 1.0332912014547824
# La ciudad ya existía Coso Junction, CA
# La ciudad ya existía Little Lake, CA
# La ciudad ya existía Olancha, CA
# La ciudad ya existía Inyokern, CA
# La ciudad ya existía Searles Valley, CA
# El evento ya existía nc 73904246
# 1.2050544147049331
# 1.210618773722811
# La ciudad ya existía Cobb, California
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Kelseyville, California
# La ciudad ya existía Middletown, California
# ...
# 1.3582595967012854
# 1.0667329553852927
# El evento ya existía nc 73904121
# La ciudad ya existía Ferndale, California
# La ciudad ya existía Fortuna, California
# La ciudad ya existía Rio Dell, California
# La ciudad ya existía Hydesville, California
# La ciudad ya existía Petrolia, California
# El evento ya existía nc 73904116
# 2.078833028304634
# La ciudad ya existía Humboldt Hill, California
# Creando ciudad Pine Hills, California
# Creando ciudad Bayview, California
# Creando ciudad Cutten, California
# La ciudad ya existía Eureka, California
# El evento ya existía nn 00861594
# 2.078833028304634
# El evento ya existía nc 73904106
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Middletown, California
# La ciudad ya existía Kelseyville, California
# El evento ya existía ci 40492496
# 1.2836669931224451
# La ciudad ya existía Bodfish, CA
# La ciudad ya existía Lake Isabella, CA
# La ciudad ya existía Wofford Heights, CA
# La ciudad ya existía Kernville, CA
# La ciudad ya existía Tehachapi, CA
# El evento ya existía ci 40492488
# 1.2836669931224451
# La ciudad ya existía Lake Isabella, CA
# La ciudad ya existía Bodfish, CA
# La ciudad ya existía Wofford Heights, CA
# La ciudad ya existía Kernville, CA
# La ciudad ya existía Inyokern, CA
# El evento ya existía ci 40492472
# La ciudad ya existía Pine Valley, CA
# La ciudad ya existía Alpine, CA
# La ciudad ya existía Jamul, CA
# La ciudad ya existía Tecate, B.C., MX
# La ciudad ya existía Campo, CA
# El evento ya existía nc 73904101
# 1.4410535372694322
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Middletown, California
# La ciudad ya existía Hidden Valley Lake, California
# El evento ya existía nc 73904096
# 1.4410535372694322
# 1.161501179687272
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Cloverdale, California
# La ciudad ya existía Kelseyville, California
# El evento ya existía nc 73904091
# 1.161501179687272
# La ciudad ya existía Parkfield, California
# La ciudad ya existía Coalinga, California
# La ciudad ya existía San Ardo, California
# La ciudad ya existía Bradley, California
# La ciudad ya existía San Miguel, California
# El evento ya existía nc 73904081
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Middletown, California
# La ciudad ya existía Hidden Valley Lake, California
# El evento ya existía nc 73904071
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cloverdale, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Kelseyville, California
# La ciudad ya existía Anderson Springs, California
# El evento ya existía nc 73904066
# 1.9697499064655124
# La ciudad ya existía Toms Place, California
# La ciudad ya existía Mammoth Lakes, California
# La ciudad ya existía Round Valley, California
# La ciudad ya existía West Bishop, California
# La ciudad ya existía Dixon Lane-Meadow Creek, California
# El evento ya existía ci 40492432
# 1.9697499064655124
# La ciudad ya existía Yucaipa, CA
# La ciudad ya existía Beaumont, CA
# La ciudad ya existía Calimesa, CA
# La ciudad ya existía Banning, CA
# La ciudad ya existía Mentone, CA
# El evento ya existía nc 73904051
# La ciudad ya existía Petrolia, California
# La ciudad ya existía Ferndale, California
# La ciudad ya existía Rio Dell, California
# La ciudad ya existía Fortuna, California
# La ciudad ya existía Eureka, California
# El evento ya existía nc 73904046
# 2.093835961211443
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Middletown, California
# La ciudad ya existía Hidden Valley Lake, California
# El evento ya existía nc 73904041
# 2.093835961211443
# 1.2892555625438824
# La ciudad ya existía Cobb, California
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Kelseyville, California
# La ciudad ya existía Soda Bay, California
# El evento ya existía nn 00861589
# 1.2892555625438824
# El evento ya existía ci 40492336
# 4.504722047661887
# 1.421433850404722
# 1.3892901382254887
# La ciudad ya existía Anza, CA
# La ciudad ya existía Warner Springs, CA
# La ciudad ya existía La Quinta, CA
# La ciudad ya existía Rancho Mirage, CA
# La ciudad ya existía Palm Desert, CA
# El evento ya existía ci 40492320
# 4.504722047661887
# 1.8713834696959055
# 1.815350354697511
# La ciudad ya existía Cabazon, CA
# La ciudad ya existía Garnet, CA
# La ciudad ya existía Banning, CA
# La ciudad ya existía Palm Springs, CA
# La ciudad ya existía Idyllwild, CA
# El evento ya existía ci 40492296
# 1.421433850404722
# 1.8713834696959055
# 58.19465549603569
# La ciudad ya existía Idyllwild, CA
# La ciudad ya existía Anza, CA
# La ciudad ya existía Valle Vista, CA
# La ciudad ya existía Hemet, CA
# La ciudad ya existía Aguanga, CA
# El evento ya existía ci 37527461
# 1.3892901382254887
# 1.815350354697511
# 58.19465549603569
# La ciudad ya existía Idyllwild, CA
# La ciudad ya existía Anza, CA
# La ciudad ya existía Valle Vista, CA
# La ciudad ya existía Hemet, CA
# La ciudad ya existía Palm Springs, CA
# El evento ya existía ci 40492264
# 2.152963456378992
# La ciudad ya existía Chula Vista, CA
# La ciudad ya existía Bonita, CA
# La ciudad ya existía San Ysidro, CA
# La ciudad ya existía Tijuana, B.C., MX
# La ciudad ya existía Imperial Beach, CA
# El evento ya existía ci 40492256
# 2.152963456378992
# La ciudad ya existía Idyllwild, CA
# La ciudad ya existía Valle Vista, CA
# La ciudad ya existía San Jacinto, CA
# La ciudad ya existía Hemet, CA
# La ciudad ya existía Anza, CA
# El evento ya existía nn 00861580
# El evento ya existía nc 73904021
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Kelseyville, California
# La ciudad ya existía Cloverdale, California
# El evento ya existía nc 73904011
# La ciudad ya existía Gonzales, California
# La ciudad ya existía Chualar, California
# La ciudad ya existía Quarry qz6 6 km ENE of Soledad, California
# La ciudad ya existía Soledad, California
# Creando ciudad Spreckels, California
# Creando ciudad Salinas, California
# El evento ya existía nc 73904006
# 5.857574146134086
# 1.105553562241273
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Kelseyville, California
# La ciudad ya existía Cloverdale, California
# El evento ya existía nc 73904001
# 5.857574146134086
# 1.3627572432445896
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Kelseyville, California
# La ciudad ya existía Cloverdale, California
# El evento ya existía nc 73903996
# 1.105553562241273
# 1.3627572432445896
# Creando ciudad Bella Vista, California
# Creando ciudad Palo Cedro, California
# Creando ciudad Millville, California
# Creando ciudad Shasta Lake, California
# La ciudad ya existía Redding, California
# El evento ya existía ci 40492184
# La ciudad ya existía Mojave, CA
# La ciudad ya existía Rosamond, CA
# La ciudad ya existía California City, CA
# La ciudad ya existía Edwards Air Force Base, CA
# La ciudad ya existía Tehachapi, CA
# El evento ya existía nc 73903991
# 1.0773986283752683
# Creando ciudad Rohnert Park, California
# Creando ciudad Roseland, California
# Creando ciudad Cotati, California
# Creando ciudad Santa Rosa, California
# La ciudad ya existía Kenwood, California
# El evento ya existía ci 40492160
# 1.0773986283752683
# La ciudad ya existía Pala, CA
# La ciudad ya existía Aguanga, CA
# La ciudad ya existía Temecula, CA
# La ciudad ya existía Palomar Observatory, CA
# Creando ciudad Murrieta Hot Springs, CA
# El evento ya existía nc 73903986
# 1.12915355231151
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Middletown, California
# La ciudad ya existía Kelseyville, California
# El evento ya existía ci 40492120
# 1.12915355231151
# 1.6823097598845194
# 1.1193547640869885
# La ciudad ya existía Yorba Linda, CA
# La ciudad ya existía Brea, CA
# La ciudad ya existía Placentia, CA
# Creando ciudad Rowland Heights, CA
# Creando ciudad La Habra, CA
# El evento ya existía ci 40492112
# 1.6823097598845194
# 3.342885074065702
# 2.0424178873110823
# La ciudad ya existía Home Gardens, CA
# La ciudad ya existía Corona, CA
# La ciudad ya existía Norco, CA
# La ciudad ya existía Woodcrest, CA
# La ciudad ya existía Riverside, CA
# El evento ya existía ci 40492096
# 1.1193547640869885
# 3.342885074065702
# 1.093225467136731
# 2.8112438225561305
# La ciudad ya existía Anza, CA
# La ciudad ya existía Idyllwild, CA
# La ciudad ya existía Aguanga, CA
# La ciudad ya existía Cathedral City, CA
# La ciudad ya existía Rancho Mirage, CA
# El evento ya existía nc 73903976
# 1.093225467136731
# 1.4773362449193417
# 2.6639336160005205
# 1.8237930500017416
# 1.194632462984089
# La ciudad ya existía Quarry q21 6 km E of Vallejo, California
# La ciudad ya existía Vallejo, California
# La ciudad ya existía Benicia, California
# La ciudad ya existía Port Costa, California
# La ciudad ya existía Crockett, California
# La ciudad ya existía American Canyon, California
# El evento ya existía ci 40492088
# 2.0424178873110823
# 2.8112438225561305
# 1.4773362449193417
# 1.4862931601745075
# La ciudad ya existía Corona, CA
# La ciudad ya existía Villa Park, CA
# Creando ciudad North Tustin, CA
# La ciudad ya existía Yorba Linda, CA
# La ciudad ya existía Home Gardens, CA
# El evento ya existía nc 73903971
# 2.6639336160005205
# 1.4862931601745075
# 2.1705680433134122
# 1.3345359469768618
# Creando ciudad Quarry q04 3 km NNE of Aromas, California
# La ciudad ya existía Aromas, California
# La ciudad ya existía San Juan Bautista, California
# Creando ciudad Las Lomas, California
# La ciudad ya existía Pajaro, California
# La ciudad ya existía Interlaken, California
# El evento ya existía nc 73903966
# 1.8237930500017416
# 2.1705680433134122
# 3.462654517803638
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Cobb, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Middletown, California
# La ciudad ya existía Hidden Valley Lake, California
# El evento ya existía nc 73903961
# 1.194632462984089
# 1.3345359469768618
# 3.462654517803638
# La ciudad ya existía Cobb, California
# La ciudad ya existía The Geysers, California
# La ciudad ya existía Anderson Springs, California
# La ciudad ya existía Kelseyville, California
# La ciudad ya existía Soda Bay, California
# El evento ya existía ci 40492072
# La ciudad ya existía Holtville, CA
# La ciudad ya existía Los Algodones, B.C., MX
# La ciudad ya existía Calipatria, CA
# La ciudad ya existía Brawley, CA
# La ciudad ya existía Niland, CA
# El evento ya existía ci 40492048
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-60dbd2f70d1a> in <cell line: 17>()
#      20     # recorro y proceso los eventos obtenidos
#      21     for feature in features:
# ---> 22       process_event(feature)
#
# <ipython-input-8-6f58047c9b7c> in process_event(feature)
#      63         # obtengo las cidades cercanas
#      64         url2 = content["url"]
# ---> 65         response2 = requests.get(url2)
#      66         if response2.status_code == 200:
#      67           cities = response2.json()
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438         try:
#     439             if not chunked:
# --> 440                 resp = conn.urlopen(
#     441                     method=request.method,
#     442                     url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712
#     713             # Make the request on the httplib connection object.
# --> 714             httplib_response = self._make_request(
#     715                 conn,
#     716                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     464                     # Python 3 (including for exceptions like SystemExit).
#     465                     # Otherwise it looks like a bug in the code.
# --> 466                     six.raise_from(e, None)
#     467         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459                 # Python 3
#     460                 try:
# --> 461                     httplib_response = conn.getresponse()
#     462                 except BaseException as e:
#     463                     # Remove the TypeError from the exception chain in
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1272                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273                   self.__class__)
# -> 1274             return self.read(nbytes, buffer)
#    1275         else:
#    1276             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1128         try:
#    1129             if buffer is not None:
# -> 1130                 return self._sslobj.read(len, buffer)
#    1131             else:
#    1132                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# función que comprueba si un evento pertenece a un cluster y lo agrega de ser así
def buscar_cluster(graph, evento):
  try:
    # parámetros para determinar si dos eventos pertenecen al mismo cluster
    alpha = 0.001 # peso de la distancia entre eventos
    beta = 0.000001 # peso del tiempo transcurrido entre eventos
    f_min = 1 # valor mínimo para considerarse cercanos
    coord = evento["coordenadas"]

    # Sentencia que trae todos los nodos que cumplen con el criterio de correlación
    sentencia = '''MATCH(c: Evento) with *,
                    point.distance(
                        point({latitude:c.coordenadas.y, longitude:c.coordenadas.x, height:c.coordenadas.z}),
                        point({latitude:$y, longitude:$x, height:$z}))/1000
                    as dist
                    with *, abs(datetime(c.fecha).epochMillis - datetime($fecha).epochMillis) as dt
                    where ID(c) > $evento_id
                    and $fmin  < 1/($alpha*dist + $beta*dt)  return c, 1/($alpha*dist + $beta*dt) as correl'''

    results = graph.run(sentencia, y=coord.y, x=coord.x, z=coord.z, fecha=evento["fecha"], fmin=f_min, alpha=alpha, beta=beta, evento_id=evento.identity).data()

    # si hay nodos correlacionados...
    if results:
      cant = len(results)
      print('Tiene', cant, 'nodos relacionados')

      # Miro si mi nodo ya está en un cluster, sino lo creo
      sentencia = '''MATCH (e: Evento)-[r]-(c: Cluster) where ID(e) = $evento_id return c'''
      clus = graph.run(sentencia, evento_id=evento.identity).data()
      if not clus:
        print('Creando cluster.')
        cluster = Node("Cluster", coordenadas = evento["coordenadas"], inicio = evento["fecha"], fin = evento["fecha"], magnitud_avg = evento["magnitud"], cant_eventos = 1)
        graph.create(cluster)
        arco = Relationship(evento, "CORRELATED", cluster)
        graph.create(arco)
      else:
          print('Cluster ya existente.')
          # El cluster ya existe, obtenemos una referencia a él
          cluster = clus[0]["c"]

      # recorro los nodos que cumplen los criterios de correlación
      i=1
      for result in results:
        print('Procesando correlacion', i, 'de', cant)
        i += 1
        evt2 = result["c"]
        correl = result["correl"]

        # me fijo si este nodo ya pertenecía a otro cluster
        sentencia = '''MATCH (e: Evento)-[r]-(c: Cluster)-[r2]-(e2: Evento) where e <> e2 and ID(e) = $evento_id and ID(c) <> $cluster_id return e2, c'''
        otro_clus = graph.run(sentencia, evento_id=evt2.identity, cluster_id = cluster.identity).data()

        # si el nodo estaba en otro cluster, busco todos los nodos de ese otro cluster y los pongo en mi nuevo cluster, lueg elimino el cluster anterior
        if otro_clus:
          print('El nodo ya estaba en otro cluster')
          otro_cluster = otro_clus[0]["c"]
          for nodos_clus in otro_clus:
            print('Cambio un nodo de cluster.')
            nodo_clus = nodos_clus["e2"]
            arco = Relationship(nodo_clus, "CORRELATED", cluster)
            graph.create(arco)
          print('Borro cluster viejo')
          graph.delete(otro_cluster)

        # Agrego el nodo al cluster
        arco = Relationship(evt2, "CORRELATED", cluster)
        graph.create(arco)
        arco = Relationship(evt2, "CORRELATION", evento, factor=correl)
        graph.create(arco)

  except Exception as e:
    print('Error en linea {}'.format(sys.exc_info()[-1].tb_lineno))
    print( str(e) )

# %%
# Recorro todos los eventos e identifico clusters

sentencia = "MATCH(e: Evento) return e ORDER BY ID(e) ASC"
results = graph.run(sentencia).data()
cant = len(results)
i = 1
for evt in results:
  node = evt["e"]
  print("Procesando Evento", i, "de", cant)
  i+=1
  buscar_cluster(graph, node)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Procesando correlacion 3 de 3
# Procesando Evento 9 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 10 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 11 de 1701
# Procesando Evento 12 de 1701
# Tiene 3 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 13 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 14 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 15 de 1701
# Procesando Evento 16 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 17 de 1701
# Procesando Evento 18 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 19 de 1701
# Procesando Evento 20 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 21 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 22 de 1701
# Procesando Evento 23 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 24 de 1701
# Procesando Evento 25 de 1701
# Procesando Evento 26 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 27 de 1701
# Procesando Evento 28 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 29 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 30 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 31 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 32 de 1701
# Procesando Evento 33 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 34 de 1701
# Procesando Evento 35 de 1701
# Procesando Evento 36 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 37 de 1701
# Procesando Evento 38 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 39 de 1701
# Procesando Evento 40 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 41 de 1701
# Procesando Evento 42 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 43 de 1701
# Procesando Evento 44 de 1701
# Procesando Evento 45 de 1701
# Procesando Evento 46 de 1701
# Procesando Evento 47 de 1701
# Procesando Evento 48 de 1701
# Procesando Evento 49 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 50 de 1701
# Procesando Evento 51 de 1701
# Procesando Evento 52 de 1701
# Procesando Evento 53 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 54 de 1701
# Procesando Evento 55 de 1701
# Procesando Evento 56 de 1701
# Procesando Evento 57 de 1701
# Procesando Evento 58 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 59 de 1701
# Procesando Evento 60 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 61 de 1701
# Procesando Evento 62 de 1701
# Procesando Evento 63 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 64 de 1701
# Procesando Evento 65 de 1701
# Procesando Evento 66 de 1701
# Procesando Evento 67 de 1701
# Procesando Evento 68 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 69 de 1701
# Procesando Evento 70 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 71 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 72 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 73 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 74 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 75 de 1701
# Procesando Evento 76 de 1701
# Procesando Evento 77 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 78 de 1701
# Procesando Evento 79 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 80 de 1701
# Procesando Evento 81 de 1701
# Procesando Evento 82 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 83 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 84 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 85 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 86 de 1701
# Procesando Evento 87 de 1701
# Procesando Evento 88 de 1701
# Tiene 3 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 89 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 90 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# El nodo ya estaba en otro cluster
# Cambio un nodo de cluster.
# Cambio un nodo de cluster.
# Cambio un nodo de cluster.
# Borro cluster viejo
# Procesando correlacion 2 de 2
# Procesando Evento 91 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 92 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 93 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 94 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 95 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 96 de 1701
# Procesando Evento 97 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 98 de 1701
# Procesando Evento 99 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 100 de 1701
# Procesando Evento 101 de 1701
# Procesando Evento 102 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 103 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 104 de 1701
# Procesando Evento 105 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 106 de 1701
# Procesando Evento 107 de 1701
# Procesando Evento 108 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 109 de 1701
# Procesando Evento 110 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 111 de 1701
# Procesando Evento 112 de 1701
# Procesando Evento 113 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 114 de 1701
# Procesando Evento 115 de 1701
# Procesando Evento 116 de 1701
# Procesando Evento 117 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 118 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 119 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# El nodo ya estaba en otro cluster
# Cambio un nodo de cluster.
# Cambio un nodo de cluster.
# Borro cluster viejo
# Procesando correlacion 2 de 2
# Procesando Evento 120 de 1701
# Procesando Evento 121 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 122 de 1701
# Procesando Evento 123 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 124 de 1701
# Procesando Evento 125 de 1701
# Procesando Evento 126 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 127 de 1701
# Procesando Evento 128 de 1701
# Procesando Evento 129 de 1701
# Procesando Evento 130 de 1701
# Procesando Evento 131 de 1701
# Procesando Evento 132 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 133 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 134 de 1701
# Procesando Evento 135 de 1701
# Procesando Evento 136 de 1701
# Procesando Evento 137 de 1701
# Procesando Evento 138 de 1701
# Procesando Evento 139 de 1701
# Procesando Evento 140 de 1701
# Procesando Evento 141 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 142 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 143 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 144 de 1701
# Procesando Evento 145 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 146 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 147 de 1701
# Procesando Evento 148 de 1701
# Procesando Evento 149 de 1701
# Procesando Evento 150 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 151 de 1701
# Procesando Evento 152 de 1701
# Procesando Evento 153 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 154 de 1701
# Procesando Evento 155 de 1701
# Procesando Evento 156 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 157 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 158 de 1701
# Procesando Evento 159 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 160 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 161 de 1701
# Procesando Evento 162 de 1701
# Procesando Evento 163 de 1701
# Procesando Evento 164 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 165 de 1701
# Procesando Evento 166 de 1701
# Procesando Evento 167 de 1701
# Procesando Evento 168 de 1701
# Procesando Evento 169 de 1701
# Procesando Evento 170 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 171 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 172 de 1701
# Procesando Evento 173 de 1701
# Procesando Evento 174 de 1701
# Procesando Evento 175 de 1701
# Procesando Evento 176 de 1701
# Procesando Evento 177 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 178 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 179 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 180 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# El nodo ya estaba en otro cluster
# Cambio un nodo de cluster.
# Borro cluster viejo
# Procesando Evento 181 de 1701
# Procesando Evento 182 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 183 de 1701
# Procesando Evento 184 de 1701
# Procesando Evento 185 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 186 de 1701
# Procesando Evento 187 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 188 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 189 de 1701
# Procesando Evento 190 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 191 de 1701
# Procesando Evento 192 de 1701
# Procesando Evento 193 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 194 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 195 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 196 de 1701
# Procesando Evento 197 de 1701
# Tiene 4 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 4
# Procesando correlacion 2 de 4
# Procesando correlacion 3 de 4
# Procesando correlacion 4 de 4
# Procesando Evento 198 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 199 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 200 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 201 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# El nodo ya estaba en otro cluster
# Cambio un nodo de cluster.
# Cambio un nodo de cluster.
# Cambio un nodo de cluster.
# Cambio un nodo de cluster.
# Borro cluster viejo
# Procesando Evento 202 de 1701
# Procesando Evento 203 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 204 de 1701
# Procesando Evento 205 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 206 de 1701
# Procesando Evento 207 de 1701
# Procesando Evento 208 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 209 de 1701
# Procesando Evento 210 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 211 de 1701
# Procesando Evento 212 de 1701
# Procesando Evento 213 de 1701
# Procesando Evento 214 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 215 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 216 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 217 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 218 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 219 de 1701
# Procesando Evento 220 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 221 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 222 de 1701
# Procesando Evento 223 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 224 de 1701
# Procesando Evento 225 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 226 de 1701
# Procesando Evento 227 de 1701
# Procesando Evento 228 de 1701
# Procesando Evento 229 de 1701
# Procesando Evento 230 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 231 de 1701
# Procesando Evento 232 de 1701
# Procesando Evento 233 de 1701
# Procesando Evento 234 de 1701
# Procesando Evento 235 de 1701
# Procesando Evento 236 de 1701
# Procesando Evento 237 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 238 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 239 de 1701
# Procesando Evento 240 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 241 de 1701
# Procesando Evento 242 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 243 de 1701
# Procesando Evento 244 de 1701
# Procesando Evento 245 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 246 de 1701
# Procesando Evento 247 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 248 de 1701
# Procesando Evento 249 de 1701
# Procesando Evento 250 de 1701
# Procesando Evento 251 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 252 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 253 de 1701
# Procesando Evento 254 de 1701
# Procesando Evento 255 de 1701
# Procesando Evento 256 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 257 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 258 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 259 de 1701
# Procesando Evento 260 de 1701
# Procesando Evento 261 de 1701
# Procesando Evento 262 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 263 de 1701
# Procesando Evento 264 de 1701
# Procesando Evento 265 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 266 de 1701
# Procesando Evento 267 de 1701
# Procesando Evento 268 de 1701
# Procesando Evento 269 de 1701
# Procesando Evento 270 de 1701
# Procesando Evento 271 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 272 de 1701
# Procesando Evento 273 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 274 de 1701
# Procesando Evento 275 de 1701
# Procesando Evento 276 de 1701
# Procesando Evento 277 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 278 de 1701
# Procesando Evento 279 de 1701
# Procesando Evento 280 de 1701
# Procesando Evento 281 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 282 de 1701
# Procesando Evento 283 de 1701
# Procesando Evento 284 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 285 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 286 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 287 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# El nodo ya estaba en otro cluster
# Cambio un nodo de cluster.
# Cambio un nodo de cluster.
# Borro cluster viejo
# Procesando Evento 288 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 289 de 1701
# Procesando Evento 290 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 291 de 1701
# Procesando Evento 292 de 1701
# Procesando Evento 293 de 1701
# Procesando Evento 294 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 295 de 1701
# Procesando Evento 296 de 1701
# Procesando Evento 297 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 298 de 1701
# Procesando Evento 299 de 1701
# Procesando Evento 300 de 1701
# Procesando Evento 301 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 302 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 303 de 1701
# Tiene 3 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 3
# El nodo ya estaba en otro cluster
# Cambio un nodo de cluster.
# Cambio un nodo de cluster.
# Borro cluster viejo
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 304 de 1701
# Procesando Evento 305 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 306 de 1701
# Procesando Evento 307 de 1701
# Procesando Evento 308 de 1701
# Procesando Evento 309 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 310 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 311 de 1701
# Procesando Evento 312 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 313 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 314 de 1701
# Procesando Evento 315 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 316 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 317 de 1701
# Procesando Evento 318 de 1701
# Procesando Evento 319 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 320 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 321 de 1701
# Procesando Evento 322 de 1701
# Procesando Evento 323 de 1701
# Tiene 3 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 324 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 325 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 326 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 327 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 328 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 329 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 330 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 331 de 1701
# Procesando Evento 332 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 333 de 1701
# Procesando Evento 334 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 335 de 1701
# Procesando Evento 336 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 337 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 338 de 1701
# Procesando Evento 339 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 340 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 341 de 1701
# Procesando Evento 342 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 343 de 1701
# Procesando Evento 344 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 345 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 346 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 347 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 348 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 349 de 1701
# Tiene 4 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 4
# El nodo ya estaba en otro cluster
# Cambio un nodo de cluster.
# Cambio un nodo de cluster.
# Borro cluster viejo
# Procesando correlacion 2 de 4
# Procesando correlacion 3 de 4
# Procesando correlacion 4 de 4
# Procesando Evento 350 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 351 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 352 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 353 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 354 de 1701
# Procesando Evento 355 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 356 de 1701
# Procesando Evento 357 de 1701
# Procesando Evento 358 de 1701
# Procesando Evento 359 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 360 de 1701
# Procesando Evento 361 de 1701
# Procesando Evento 362 de 1701
# Procesando Evento 363 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 364 de 1701
# Procesando Evento 365 de 1701
# Procesando Evento 366 de 1701
# Procesando Evento 367 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 368 de 1701
# Procesando Evento 369 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 370 de 1701
# Procesando Evento 371 de 1701
# Procesando Evento 372 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 373 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 374 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 375 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 376 de 1701
# Procesando Evento 377 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 378 de 1701
# Procesando Evento 379 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 380 de 1701
# Procesando Evento 381 de 1701
# Procesando Evento 382 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 383 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 384 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 385 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 386 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 387 de 1701
# Procesando Evento 388 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 389 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 390 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 391 de 1701
# Procesando Evento 392 de 1701
# Procesando Evento 393 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 394 de 1701
# Procesando Evento 395 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 396 de 1701
# Procesando Evento 397 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 398 de 1701
# Procesando Evento 399 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 400 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# El nodo ya estaba en otro cluster
# Cambio un nodo de cluster.
# Borro cluster viejo
# Procesando Evento 401 de 1701
# Procesando Evento 402 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 403 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 404 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 405 de 1701
# Procesando Evento 406 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 407 de 1701
# Procesando Evento 408 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 409 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 410 de 1701
# Procesando Evento 411 de 1701
# Procesando Evento 412 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 413 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 414 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 415 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 416 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 417 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 418 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 419 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 420 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 421 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# El nodo ya estaba en otro cluster
# Cambio un nodo de cluster.
# Cambio un nodo de cluster.
# Cambio un nodo de cluster.
# Cambio un nodo de cluster.
# Cambio un nodo de cluster.
# Cambio un nodo de cluster.
# Cambio un nodo de cluster.
# Cambio un nodo de cluster.
# Cambio un nodo de cluster.
# Borro cluster viejo
# Procesando Evento 422 de 1701
# Procesando Evento 423 de 1701
# Procesando Evento 424 de 1701
# Procesando Evento 425 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 426 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 427 de 1701
# Procesando Evento 428 de 1701
# Procesando Evento 429 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 430 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 431 de 1701
# Procesando Evento 432 de 1701
# Procesando Evento 433 de 1701
# Procesando Evento 434 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 435 de 1701
# Procesando Evento 436 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 437 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 438 de 1701
# Tiene 4 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 4
# Procesando correlacion 2 de 4
# Procesando correlacion 3 de 4
# Procesando correlacion 4 de 4
# Procesando Evento 439 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 440 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 441 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 442 de 1701
# Procesando Evento 443 de 1701
# Procesando Evento 444 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 445 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 446 de 1701
# Procesando Evento 447 de 1701
# Procesando Evento 448 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 449 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 450 de 1701
# Procesando Evento 451 de 1701
# Tiene 3 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 452 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 453 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 454 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 455 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 456 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 457 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 458 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 459 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 460 de 1701
# Procesando Evento 461 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 462 de 1701
# Procesando Evento 463 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 464 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 465 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 466 de 1701
# Procesando Evento 467 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 468 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 469 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 470 de 1701
# Procesando Evento 471 de 1701
# Procesando Evento 472 de 1701
# Tiene 3 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 473 de 1701
# Tiene 6 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 6
# Procesando correlacion 2 de 6
# Procesando correlacion 3 de 6
# Procesando correlacion 4 de 6
# Procesando correlacion 5 de 6
# Procesando correlacion 6 de 6
# Procesando Evento 474 de 1701
# Tiene 5 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 5
# Procesando correlacion 2 de 5
# Procesando correlacion 3 de 5
# Procesando correlacion 4 de 5
# Procesando correlacion 5 de 5
# Procesando Evento 475 de 1701
# Tiene 4 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 4
# Procesando correlacion 2 de 4
# Procesando correlacion 3 de 4
# Procesando correlacion 4 de 4
# Procesando Evento 476 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 477 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 478 de 1701
# Tiene 4 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 4
# Procesando correlacion 2 de 4
# Procesando correlacion 3 de 4
# Procesando correlacion 4 de 4
# Procesando Evento 479 de 1701
# Tiene 5 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 5
# Procesando correlacion 2 de 5
# Procesando correlacion 3 de 5
# Procesando correlacion 4 de 5
# Procesando correlacion 5 de 5
# Procesando Evento 480 de 1701
# Tiene 4 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 4
# Procesando correlacion 2 de 4
# Procesando correlacion 3 de 4
# Procesando correlacion 4 de 4
# Procesando Evento 481 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 482 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 483 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 484 de 1701
# Procesando Evento 485 de 1701
# Procesando Evento 486 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 487 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 488 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 489 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 490 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 491 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 492 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 493 de 1701
# Procesando Evento 494 de 1701
# Procesando Evento 495 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 496 de 1701
# Procesando Evento 497 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 498 de 1701
# Procesando Evento 499 de 1701
# Procesando Evento 500 de 1701
# Procesando Evento 501 de 1701
# Tiene 3 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 502 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 503 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 504 de 1701
# Procesando Evento 505 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 506 de 1701
# Procesando Evento 507 de 1701
# Procesando Evento 508 de 1701
# Procesando Evento 509 de 1701
# Procesando Evento 510 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 511 de 1701
# Procesando Evento 512 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 513 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 514 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 515 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 516 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 517 de 1701
# Procesando Evento 518 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 519 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 520 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 521 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 522 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 523 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 524 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 525 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 526 de 1701
# Procesando Evento 527 de 1701
# Procesando Evento 528 de 1701
# Procesando Evento 529 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 530 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 531 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 532 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 533 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# El nodo ya estaba en otro cluster
# Cambio un nodo de cluster.
# Cambio un nodo de cluster.
# Cambio un nodo de cluster.
# Cambio un nodo de cluster.
# Borro cluster viejo
# Procesando Evento 534 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 535 de 1701
# Procesando Evento 536 de 1701
# Procesando Evento 537 de 1701
# Tiene 8 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 8
# Procesando correlacion 2 de 8
# Procesando correlacion 3 de 8
# Procesando correlacion 4 de 8
# Procesando correlacion 5 de 8
# Procesando correlacion 6 de 8
# Procesando correlacion 7 de 8
# Procesando correlacion 8 de 8
# Procesando Evento 538 de 1701
# Tiene 7 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 7
# Procesando correlacion 2 de 7
# Procesando correlacion 3 de 7
# Procesando correlacion 4 de 7
# Procesando correlacion 5 de 7
# Procesando correlacion 6 de 7
# Procesando correlacion 7 de 7
# Procesando Evento 539 de 1701
# Tiene 6 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 6
# Procesando correlacion 2 de 6
# Procesando correlacion 3 de 6
# Procesando correlacion 4 de 6
# Procesando correlacion 5 de 6
# Procesando correlacion 6 de 6
# Procesando Evento 540 de 1701
# Tiene 5 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 5
# Procesando correlacion 2 de 5
# Procesando correlacion 3 de 5
# Procesando correlacion 4 de 5
# Procesando correlacion 5 de 5
# Procesando Evento 541 de 1701
# Tiene 4 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 4
# Procesando correlacion 2 de 4
# Procesando correlacion 3 de 4
# Procesando correlacion 4 de 4
# Procesando Evento 542 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 543 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 544 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 545 de 1701
# Procesando Evento 546 de 1701
# Procesando Evento 547 de 1701
# Procesando Evento 548 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 549 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 550 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 551 de 1701
# Procesando Evento 552 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 553 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 554 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 555 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 556 de 1701
# Procesando Evento 557 de 1701
# Procesando Evento 558 de 1701
# Procesando Evento 559 de 1701
# Procesando Evento 560 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 561 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 562 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 563 de 1701
# Procesando Evento 564 de 1701
# Procesando Evento 565 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 566 de 1701
# Procesando Evento 567 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 568 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 569 de 1701
# Procesando Evento 570 de 1701
# Procesando Evento 571 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 572 de 1701
# Procesando Evento 573 de 1701
# Procesando Evento 574 de 1701
# Procesando Evento 575 de 1701
# Procesando Evento 576 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 577 de 1701
# Procesando Evento 578 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 579 de 1701
# Procesando Evento 580 de 1701
# Procesando Evento 581 de 1701
# Procesando Evento 582 de 1701
# Procesando Evento 583 de 1701
# Procesando Evento 584 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 585 de 1701
# Procesando Evento 586 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 587 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 588 de 1701
# Procesando Evento 589 de 1701
# Procesando Evento 590 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# ...
# Procesando Evento 1507 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1508 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1509 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1510 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1511 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1512 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1513 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1514 de 1701
# Procesando Evento 1515 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1516 de 1701
# Procesando Evento 1517 de 1701
# Procesando Evento 1518 de 1701
# Procesando Evento 1519 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1520 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1521 de 1701
# Procesando Evento 1522 de 1701
# Procesando Evento 1523 de 1701
# Procesando Evento 1524 de 1701
# Procesando Evento 1525 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1526 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1527 de 1701
# Procesando Evento 1528 de 1701
# Procesando Evento 1529 de 1701
# Procesando Evento 1530 de 1701
# Procesando Evento 1531 de 1701
# Tiene 3 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 1532 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1533 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 1534 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1535 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1536 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1537 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1538 de 1701
# Procesando Evento 1539 de 1701
# Procesando Evento 1540 de 1701
# Procesando Evento 1541 de 1701
# Procesando Evento 1542 de 1701
# Procesando Evento 1543 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1544 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1545 de 1701
# Procesando Evento 1546 de 1701
# Procesando Evento 1547 de 1701
# Procesando Evento 1548 de 1701
# Procesando Evento 1549 de 1701
# Procesando Evento 1550 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1551 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1552 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1553 de 1701
# Procesando Evento 1554 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1555 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1556 de 1701
# Procesando Evento 1557 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1558 de 1701
# Procesando Evento 1559 de 1701
# Procesando Evento 1560 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1561 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# El nodo ya estaba en otro cluster
# Cambio un nodo de cluster.
# Borro cluster viejo
# Procesando Evento 1562 de 1701
# Procesando Evento 1563 de 1701
# Procesando Evento 1564 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1565 de 1701
# Procesando Evento 1566 de 1701
# Procesando Evento 1567 de 1701
# Tiene 3 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 1568 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1569 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1570 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1571 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1572 de 1701
# Procesando Evento 1573 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1574 de 1701
# Procesando Evento 1575 de 1701
# Tiene 3 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 1576 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1577 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1578 de 1701
# Procesando Evento 1579 de 1701
# Procesando Evento 1580 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1581 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1582 de 1701
# Procesando Evento 1583 de 1701
# Procesando Evento 1584 de 1701
# Tiene 5 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 5
# Procesando correlacion 2 de 5
# Procesando correlacion 3 de 5
# Procesando correlacion 4 de 5
# Procesando correlacion 5 de 5
# Procesando Evento 1585 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1586 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 1587 de 1701
# Procesando Evento 1588 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1589 de 1701
# Procesando Evento 1590 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1591 de 1701
# Procesando Evento 1592 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1593 de 1701
# Procesando Evento 1594 de 1701
# Procesando Evento 1595 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1596 de 1701
# Tiene 3 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 3
# El nodo ya estaba en otro cluster
# Cambio un nodo de cluster.
# Cambio un nodo de cluster.
# Borro cluster viejo
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 1597 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1598 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1599 de 1701
# Procesando Evento 1600 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1601 de 1701
# Procesando Evento 1602 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1603 de 1701
# Procesando Evento 1604 de 1701
# Procesando Evento 1605 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1606 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1607 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1608 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1609 de 1701
# Procesando Evento 1610 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1611 de 1701
# Procesando Evento 1612 de 1701
# Procesando Evento 1613 de 1701
# Procesando Evento 1614 de 1701
# Procesando Evento 1615 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1616 de 1701
# Procesando Evento 1617 de 1701
# Procesando Evento 1618 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1619 de 1701
# Procesando Evento 1620 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1621 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1622 de 1701
# Procesando Evento 1623 de 1701
# Tiene 5 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 5
# Procesando correlacion 2 de 5
# Procesando correlacion 3 de 5
# Procesando correlacion 4 de 5
# Procesando correlacion 5 de 5
# Procesando Evento 1624 de 1701
# Tiene 4 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 4
# Procesando correlacion 2 de 4
# Procesando correlacion 3 de 4
# Procesando correlacion 4 de 4
# Procesando Evento 1625 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 1626 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1627 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1628 de 1701
# Procesando Evento 1629 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1630 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1631 de 1701
# Procesando Evento 1632 de 1701
# Procesando Evento 1633 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1634 de 1701
# Procesando Evento 1635 de 1701
# Procesando Evento 1636 de 1701
# Procesando Evento 1637 de 1701
# Procesando Evento 1638 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1639 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1640 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1641 de 1701
# Procesando Evento 1642 de 1701
# Procesando Evento 1643 de 1701
# Procesando Evento 1644 de 1701
# Procesando Evento 1645 de 1701
# Procesando Evento 1646 de 1701
# Procesando Evento 1647 de 1701
# Procesando Evento 1648 de 1701
# Procesando Evento 1649 de 1701
# Procesando Evento 1650 de 1701
# Procesando Evento 1651 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1652 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 1653 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1654 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1655 de 1701
# Procesando Evento 1656 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1657 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1658 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1659 de 1701
# Procesando Evento 1660 de 1701
# Tiene 3 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 1661 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1662 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1663 de 1701
# Procesando Evento 1664 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1665 de 1701
# Procesando Evento 1666 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1667 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1668 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1669 de 1701
# Procesando Evento 1670 de 1701
# Procesando Evento 1671 de 1701
# Procesando Evento 1672 de 1701
# Procesando Evento 1673 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1674 de 1701
# Procesando Evento 1675 de 1701
# Procesando Evento 1676 de 1701
# Procesando Evento 1677 de 1701
# Procesando Evento 1678 de 1701
# Tiene 2 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1679 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1680 de 1701
# Procesando Evento 1681 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1682 de 1701
# Procesando Evento 1683 de 1701
# Procesando Evento 1684 de 1701
# Procesando Evento 1685 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1686 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1687 de 1701
# Procesando Evento 1688 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1689 de 1701
# Procesando Evento 1690 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1691 de 1701
# Procesando Evento 1692 de 1701
# Procesando Evento 1693 de 1701
# Tiene 5 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 5
# Procesando correlacion 2 de 5
# Procesando correlacion 3 de 5
# Procesando correlacion 4 de 5
# Procesando correlacion 5 de 5
# Procesando Evento 1694 de 1701
# Tiene 4 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 4
# Procesando correlacion 2 de 4
# Procesando correlacion 3 de 4
# Procesando correlacion 4 de 4
# Procesando Evento 1695 de 1701
# Tiene 3 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 3
# Procesando correlacion 2 de 3
# Procesando correlacion 3 de 3
# Procesando Evento 1696 de 1701
# Tiene 2 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 2
# Procesando correlacion 2 de 2
# Procesando Evento 1697 de 1701
# Tiene 1 nodos relacionados
# Cluster ya existente.
# Procesando correlacion 1 de 1
# Procesando Evento 1698 de 1701
# Procesando Evento 1699 de 1701
# Procesando Evento 1700 de 1701
# Tiene 1 nodos relacionados
# Creando cluster.
# Procesando correlacion 1 de 1
# Procesando Evento 1701 de 1701

# %%
# Recorro todos los clusters para actualizar sus valores

sentencia = '''Match(c:Cluster)-[r]-(e:Evento)
                return c,
                count(e) as cant,
                min(e.fecha) as ini,
                max(e.fecha) as fn,
                avg(e.magnitud) as mag,
                point({x: avg(e.coordenadas.x), y: avg(e.coordenadas.y), z: avg(e.coordenadas.z)}) as cord'''
results = graph.run(sentencia).data()
cant = len(results)
i = 1
for cluster in results:
  node = cluster["c"]
  node["inicio"] = cluster["ini"]
  node["fin"] = cluster["fn"]
  node["magnitud_avg"] = cluster["mag"]
  node["coordenadas"] = cluster["cord"]
  node["cant_eventos"] = cluster["cant"]
  graph.push(node)
  print("Procesando Cluster", i, "de", cant)
  i+=1
# Out:
# Procesando Cluster 1 de 387
# Procesando Cluster 2 de 387
# Procesando Cluster 3 de 387
# Procesando Cluster 4 de 387
# Procesando Cluster 5 de 387
# Procesando Cluster 6 de 387
# Procesando Cluster 7 de 387
# Procesando Cluster 8 de 387
# Procesando Cluster 9 de 387
# Procesando Cluster 10 de 387
# Procesando Cluster 11 de 387
# Procesando Cluster 12 de 387
# Procesando Cluster 13 de 387
# Procesando Cluster 14 de 387
# Procesando Cluster 15 de 387
# Procesando Cluster 16 de 387
# Procesando Cluster 17 de 387
# Procesando Cluster 18 de 387
# Procesando Cluster 19 de 387
# Procesando Cluster 20 de 387
# Procesando Cluster 21 de 387
# Procesando Cluster 22 de 387
# Procesando Cluster 23 de 387
# Procesando Cluster 24 de 387
# Procesando Cluster 25 de 387
# Procesando Cluster 26 de 387
# Procesando Cluster 27 de 387
# Procesando Cluster 28 de 387
# Procesando Cluster 29 de 387
# Procesando Cluster 30 de 387
# Procesando Cluster 31 de 387
# Procesando Cluster 32 de 387
# Procesando Cluster 33 de 387
# Procesando Cluster 34 de 387
# Procesando Cluster 35 de 387
# Procesando Cluster 36 de 387
# Procesando Cluster 37 de 387
# Procesando Cluster 38 de 387
# Procesando Cluster 39 de 387
# Procesando Cluster 40 de 387
# Procesando Cluster 41 de 387
# Procesando Cluster 42 de 387
# Procesando Cluster 43 de 387
# Procesando Cluster 44 de 387
# Procesando Cluster 45 de 387
# Procesando Cluster 46 de 387
# Procesando Cluster 47 de 387
# Procesando Cluster 48 de 387
# Procesando Cluster 49 de 387
# Procesando Cluster 50 de 387
# Procesando Cluster 51 de 387
# Procesando Cluster 52 de 387
# Procesando Cluster 53 de 387
# Procesando Cluster 54 de 387
# Procesando Cluster 55 de 387
# Procesando Cluster 56 de 387
# Procesando Cluster 57 de 387
# Procesando Cluster 58 de 387
# Procesando Cluster 59 de 387
# Procesando Cluster 60 de 387
# Procesando Cluster 61 de 387
# Procesando Cluster 62 de 387
# Procesando Cluster 63 de 387
# Procesando Cluster 64 de 387
# Procesando Cluster 65 de 387
# Procesando Cluster 66 de 387
# Procesando Cluster 67 de 387
# Procesando Cluster 68 de 387
# Procesando Cluster 69 de 387
# Procesando Cluster 70 de 387
# Procesando Cluster 71 de 387
# Procesando Cluster 72 de 387
# Procesando Cluster 73 de 387
# Procesando Cluster 74 de 387
# Procesando Cluster 75 de 387
# Procesando Cluster 76 de 387
# Procesando Cluster 77 de 387
# Procesando Cluster 78 de 387
# Procesando Cluster 79 de 387
# Procesando Cluster 80 de 387
# Procesando Cluster 81 de 387
# Procesando Cluster 82 de 387
# Procesando Cluster 83 de 387
# Procesando Cluster 84 de 387
# Procesando Cluster 85 de 387
# Procesando Cluster 86 de 387
# Procesando Cluster 87 de 387
# Procesando Cluster 88 de 387
# Procesando Cluster 89 de 387
# Procesando Cluster 90 de 387
# Procesando Cluster 91 de 387
# Procesando Cluster 92 de 387
# Procesando Cluster 93 de 387
# Procesando Cluster 94 de 387
# Procesando Cluster 95 de 387
# Procesando Cluster 96 de 387
# Procesando Cluster 97 de 387
# Procesando Cluster 98 de 387
# Procesando Cluster 99 de 387
# Procesando Cluster 100 de 387
# Procesando Cluster 101 de 387
# Procesando Cluster 102 de 387
# Procesando Cluster 103 de 387
# Procesando Cluster 104 de 387
# Procesando Cluster 105 de 387
# Procesando Cluster 106 de 387
# Procesando Cluster 107 de 387
# Procesando Cluster 108 de 387
# Procesando Cluster 109 de 387
# Procesando Cluster 110 de 387
# Procesando Cluster 111 de 387
# Procesando Cluster 112 de 387
# Procesando Cluster 113 de 387
# Procesando Cluster 114 de 387
# Procesando Cluster 115 de 387
# Procesando Cluster 116 de 387
# Procesando Cluster 117 de 387
# Procesando Cluster 118 de 387
# Procesando Cluster 119 de 387
# Procesando Cluster 120 de 387
# Procesando Cluster 121 de 387
# Procesando Cluster 122 de 387
# Procesando Cluster 123 de 387
# Procesando Cluster 124 de 387
# Procesando Cluster 125 de 387
# Procesando Cluster 126 de 387
# Procesando Cluster 127 de 387
# Procesando Cluster 128 de 387
# Procesando Cluster 129 de 387
# Procesando Cluster 130 de 387
# Procesando Cluster 131 de 387
# Procesando Cluster 132 de 387
# Procesando Cluster 133 de 387
# Procesando Cluster 134 de 387
# Procesando Cluster 135 de 387
# Procesando Cluster 136 de 387
# Procesando Cluster 137 de 387
# Procesando Cluster 138 de 387
# Procesando Cluster 139 de 387
# Procesando Cluster 140 de 387
# Procesando Cluster 141 de 387
# Procesando Cluster 142 de 387
# Procesando Cluster 143 de 387
# Procesando Cluster 144 de 387
# Procesando Cluster 145 de 387
# Procesando Cluster 146 de 387
# Procesando Cluster 147 de 387
# Procesando Cluster 148 de 387
# Procesando Cluster 149 de 387
# Procesando Cluster 150 de 387
# Procesando Cluster 151 de 387
# Procesando Cluster 152 de 387
# Procesando Cluster 153 de 387
# Procesando Cluster 154 de 387
# Procesando Cluster 155 de 387
# Procesando Cluster 156 de 387
# Procesando Cluster 157 de 387
# Procesando Cluster 158 de 387
# Procesando Cluster 159 de 387
# Procesando Cluster 160 de 387
# Procesando Cluster 161 de 387
# Procesando Cluster 162 de 387
# Procesando Cluster 163 de 387
# Procesando Cluster 164 de 387
# Procesando Cluster 165 de 387
# Procesando Cluster 166 de 387
# Procesando Cluster 167 de 387
# Procesando Cluster 168 de 387
# Procesando Cluster 169 de 387
# Procesando Cluster 170 de 387
# Procesando Cluster 171 de 387
# Procesando Cluster 172 de 387
# Procesando Cluster 173 de 387
# Procesando Cluster 174 de 387
# Procesando Cluster 175 de 387
# Procesando Cluster 176 de 387
# Procesando Cluster 177 de 387
# Procesando Cluster 178 de 387
# Procesando Cluster 179 de 387
# Procesando Cluster 180 de 387
# Procesando Cluster 181 de 387
# Procesando Cluster 182 de 387
# Procesando Cluster 183 de 387
# Procesando Cluster 184 de 387
# Procesando Cluster 185 de 387
# Procesando Cluster 186 de 387
# Procesando Cluster 187 de 387
# Procesando Cluster 188 de 387
# Procesando Cluster 189 de 387
# Procesando Cluster 190 de 387
# Procesando Cluster 191 de 387
# Procesando Cluster 192 de 387
# Procesando Cluster 193 de 387
# Procesando Cluster 194 de 387
# Procesando Cluster 195 de 387
# Procesando Cluster 196 de 387
# Procesando Cluster 197 de 387
# Procesando Cluster 198 de 387
# Procesando Cluster 199 de 387
# Procesando Cluster 200 de 387
# Procesando Cluster 201 de 387
# Procesando Cluster 202 de 387
# Procesando Cluster 203 de 387
# Procesando Cluster 204 de 387
# Procesando Cluster 205 de 387
# Procesando Cluster 206 de 387
# Procesando Cluster 207 de 387
# Procesando Cluster 208 de 387
# Procesando Cluster 209 de 387
# Procesando Cluster 210 de 387
# Procesando Cluster 211 de 387
# Procesando Cluster 212 de 387
# Procesando Cluster 213 de 387
# Procesando Cluster 214 de 387
# Procesando Cluster 215 de 387
# Procesando Cluster 216 de 387
# Procesando Cluster 217 de 387
# Procesando Cluster 218 de 387
# Procesando Cluster 219 de 387
# Procesando Cluster 220 de 387
# Procesando Cluster 221 de 387
# Procesando Cluster 222 de 387
# Procesando Cluster 223 de 387
# Procesando Cluster 224 de 387
# Procesando Cluster 225 de 387
# Procesando Cluster 226 de 387
# Procesando Cluster 227 de 387
# Procesando Cluster 228 de 387
# Procesando Cluster 229 de 387
# Procesando Cluster 230 de 387
# Procesando Cluster 231 de 387
# Procesando Cluster 232 de 387
# Procesando Cluster 233 de 387
# Procesando Cluster 234 de 387
# Procesando Cluster 235 de 387
# Procesando Cluster 236 de 387
# Procesando Cluster 237 de 387
# Procesando Cluster 238 de 387
# Procesando Cluster 239 de 387
# Procesando Cluster 240 de 387
# Procesando Cluster 241 de 387
# Procesando Cluster 242 de 387
# Procesando Cluster 243 de 387
# Procesando Cluster 244 de 387
# Procesando Cluster 245 de 387
# Procesando Cluster 246 de 387
# Procesando Cluster 247 de 387
# Procesando Cluster 248 de 387
# Procesando Cluster 249 de 387
# Procesando Cluster 250 de 387
# Procesando Cluster 251 de 387
# Procesando Cluster 252 de 387
# Procesando Cluster 253 de 387
# Procesando Cluster 254 de 387
# Procesando Cluster 255 de 387
# Procesando Cluster 256 de 387
# Procesando Cluster 257 de 387
# Procesando Cluster 258 de 387
# Procesando Cluster 259 de 387
# Procesando Cluster 260 de 387
# Procesando Cluster 261 de 387
# Procesando Cluster 262 de 387
# Procesando Cluster 263 de 387
# Procesando Cluster 264 de 387
# Procesando Cluster 265 de 387
# Procesando Cluster 266 de 387
# Procesando Cluster 267 de 387
# Procesando Cluster 268 de 387
# Procesando Cluster 269 de 387
# Procesando Cluster 270 de 387
# Procesando Cluster 271 de 387
# Procesando Cluster 272 de 387
# Procesando Cluster 273 de 387
# Procesando Cluster 274 de 387
# Procesando Cluster 275 de 387
# Procesando Cluster 276 de 387
# Procesando Cluster 277 de 387
# Procesando Cluster 278 de 387
# Procesando Cluster 279 de 387
# Procesando Cluster 280 de 387
# Procesando Cluster 281 de 387
# Procesando Cluster 282 de 387
# Procesando Cluster 283 de 387
# Procesando Cluster 284 de 387
# Procesando Cluster 285 de 387
# Procesando Cluster 286 de 387
# Procesando Cluster 287 de 387
# Procesando Cluster 288 de 387
# Procesando Cluster 289 de 387
# Procesando Cluster 290 de 387
# Procesando Cluster 291 de 387
# Procesando Cluster 292 de 387
# Procesando Cluster 293 de 387
# Procesando Cluster 294 de 387
# Procesando Cluster 295 de 387
# Procesando Cluster 296 de 387
# Procesando Cluster 297 de 387
# Procesando Cluster 298 de 387
# Procesando Cluster 299 de 387
# Procesando Cluster 300 de 387
# Procesando Cluster 301 de 387
# Procesando Cluster 302 de 387
# Procesando Cluster 303 de 387
# Procesando Cluster 304 de 387
# Procesando Cluster 305 de 387
# Procesando Cluster 306 de 387
# Procesando Cluster 307 de 387
# Procesando Cluster 308 de 387
# Procesando Cluster 309 de 387
# Procesando Cluster 310 de 387
# Procesando Cluster 311 de 387
# Procesando Cluster 312 de 387
# Procesando Cluster 313 de 387
# Procesando Cluster 314 de 387
# Procesando Cluster 315 de 387
# Procesando Cluster 316 de 387
# Procesando Cluster 317 de 387
# Procesando Cluster 318 de 387
# Procesando Cluster 319 de 387
# Procesando Cluster 320 de 387
# Procesando Cluster 321 de 387
# Procesando Cluster 322 de 387
# Procesando Cluster 323 de 387
# Procesando Cluster 324 de 387
# Procesando Cluster 325 de 387
# Procesando Cluster 326 de 387
# Procesando Cluster 327 de 387
# Procesando Cluster 328 de 387
# Procesando Cluster 329 de 387
# Procesando Cluster 330 de 387
# Procesando Cluster 331 de 387
# Procesando Cluster 332 de 387
# Procesando Cluster 333 de 387
# Procesando Cluster 334 de 387
# Procesando Cluster 335 de 387
# Procesando Cluster 336 de 387
# Procesando Cluster 337 de 387
# Procesando Cluster 338 de 387
# Procesando Cluster 339 de 387
# Procesando Cluster 340 de 387
# Procesando Cluster 341 de 387
# Procesando Cluster 342 de 387
# Procesando Cluster 343 de 387
# Procesando Cluster 344 de 387
# Procesando Cluster 345 de 387
# Procesando Cluster 346 de 387
# Procesando Cluster 347 de 387
# Procesando Cluster 348 de 387
# Procesando Cluster 349 de 387
# Procesando Cluster 350 de 387
# Procesando Cluster 351 de 387
# Procesando Cluster 352 de 387
# Procesando Cluster 353 de 387
# Procesando Cluster 354 de 387
# Procesando Cluster 355 de 387
# Procesando Cluster 356 de 387
# Procesando Cluster 357 de 387
# Procesando Cluster 358 de 387
# Procesando Cluster 359 de 387
# Procesando Cluster 360 de 387
# Procesando Cluster 361 de 387
# Procesando Cluster 362 de 387
# Procesando Cluster 363 de 387
# Procesando Cluster 364 de 387
# Procesando Cluster 365 de 387
# Procesando Cluster 366 de 387
# Procesando Cluster 367 de 387
# Procesando Cluster 368 de 387
# Procesando Cluster 369 de 387
# Procesando Cluster 370 de 387
# Procesando Cluster 371 de 387
# Procesando Cluster 372 de 387
# Procesando Cluster 373 de 387
# Procesando Cluster 374 de 387
# Procesando Cluster 375 de 387
# Procesando Cluster 376 de 387
# Procesando Cluster 377 de 387
# Procesando Cluster 378 de 387
# Procesando Cluster 379 de 387
# Procesando Cluster 380 de 387
# Procesando Cluster 381 de 387
# Procesando Cluster 382 de 387
# Procesando Cluster 383 de 387
# Procesando Cluster 384 de 387
# Procesando Cluster 385 de 387
# Procesando Cluster 386 de 387
# Procesando Cluster 387 de 387
